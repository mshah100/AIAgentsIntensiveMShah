# %% [markdown]
# # Agents Intensive - Capstone Project - Monisha Shah
#
# **Kaggle 5-day Agents course!**
#
# Creating agents to get the recipes for sugar free deserts along with Ingredients.
#
# Using a Sequential Agents to retrieve the recipe for the desert and where to buy the ingredients from.

# %% [markdown]
# ### Install dependencies google agent development kit library
#
# The Kaggle Notebooks environment includes a pre-installed version of the [google-adk](https://google.github.io/adk-docs/) library for Python and its required dependencies, so you don't need to install additional packages in this notebook.
#
# To install and use ADK in your own Python development environment outside of this course, you can do so by running:
#
# ```
# pip install google-adk
# ```

# %% [markdown]
# ### Configure your Gemini API Key
#
# This notebook uses the [Gemini API](https://ai.google.dev/gemini-api/docs), which requires authentication.
#
# **1. Get your API key**
#
# If you don't have one already, create an [API key in Google AI Studio](https://aistudio.google.com/app/api-keys).
#
# **2. Add the key to Kaggle Secrets**
#
# Next, you will need to add your API key to your Kaggle Notebook as a Kaggle User Secret.
#
# 1. In the top menu bar of the notebook editor, select `Add-ons` then `Secrets`.
# 2. Create a new secret with the label `GOOGLE_API_KEY`.
# 3. Paste your API key into the "Value" field and click "Save".
# 4. Ensure that the checkbox next to `GOOGLE_API_KEY` is selected so that the secret is attached to the notebook.
#
# **3. Authenticate in the notebook**
#
# Run the cell below to complete authentication.

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ### Import ADK components
#
# Now, import the specific components you'll need from the Agent Development Kit and the Generative AI library. This keeps your code organized and ensures we have access to the necessary building blocks.

# %%
from google.adk.agents import Agent, LlmAgent, SequentialAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types



from google.adk.tools.mcp_tool.mcp_toolset import McpToolset
from google.adk.tools.tool_context import ToolContext
from google.adk.tools.mcp_tool.mcp_session_manager import StdioConnectionParams
from mcp import StdioServerParameters

from google.adk.apps.app import App, ResumabilityConfig
from google.adk.tools.function_tool import FunctionTool
from google.adk.sessions import InMemorySessionService

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ### Helper functions
#
# We'll define some helper functions. If you are running this outside the Kaggle environment, you don't need to do this.

# %%
# Define helper functions that will be reused throughout the notebook

from IPython.core.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# ### Configure Retry Options
#
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# ---
#
# ## AI Agent with ADK
#
# ### What is an AI Agent?
#
# You've probably used an LLM like Gemini before, where you give it a prompt and it gives you a text response.
#
# `Prompt -> LLM -> Text`
#
# An AI Agent takes this one step further. An agent can think, take actions, and observe the results of those actions to give you a better answer.
#
# `Prompt -> Agent -> Thought -> Action -> Observation -> Final Answer`
#
# In this notebook, we'll build an agent that can take the action of searching Google. Let's see the difference!

# %% [markdown]
# ### Define your agent
#
# Now, let's build our agent. We'll configure an `Agent` by setting its key properties, which tell it what to do and how to operate.
#
# To learn more, check out the documentation related to [agents in ADK](https://google.github.io/adk-docs/agents/).
#
# These are the main properties we'll set:
#
# - **name** and **description**: A simple name and description to identify our agent.
# - **model**: The specific LLM that will power the agent's reasoning. We'll use "gemini-2.5-flash-lite".
# - **instruction**: The agent's guiding prompt. This tells the agent what its goal is and how to behave.
# - **tools**: A list of [tools](https://google.github.io/adk-docs/tools/) that the agent can use. To start, we'll give it the `google_search` tool, which lets it find up-to-date information online.

# %% [markdown]
# **Agent that helps retrieve the sugar free recipes**

# %%
recipe_agent = Agent(
    name="recipe_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the recipes of all sugarfree deserts using dried dates, figs and raisins.",
    instruction="You are a helpful assistant. Use Google Search to get the recipe for the sugarfree dessert.",
    tools=[google_search],
    output_key="recipe_generated",  # The result will be stored with this key.
)

print("✅ Recipe Agent defined.")
# Out:
# ✅ Recipe Agent defined.

# %% [markdown]
# **Ingredients Agent created to get all the ingredients only for the summary?**

# %%
ingredients_agent = Agent(
    name="ingredients_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the recipes of all sugarfree deserts using dried dates, figs and raisins.",
    instruction="Please only give me the ingredients for the recipe for the sugarfree dessert. {recipe_generated}",
    output_key="ingredients_generated",  # The result will be stored with this key.
)

print("✅ Ingredients Agent defined.")
# Out:
# ✅ Ingredients Agent defined.

# %% [markdown]
# **Agent to retrieve the couple stores the ingredients are available at?******

# %%
store_suggestion_agent = Agent(
    name="ingredients_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that get you the stores to buy the ingredients from?",
    instruction="Please give me the top 2 stores where the ingredients can be bought?. {ingredients_generated}",
    output_key="stores_suggestion_generated",  # The result will be stored with this key.
)

print("✅ Stores Suggestion Agent defined.")
# Out:
# ✅ Stores Suggestion Agent defined.

# %% [markdown]
# **Agent to get the cumulative pricing for the ingredients**

# %%
price_estimation_agent = Agent(
    name="price_estimation_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the prices of theingredients",
    instruction="Please give me the prices of all the ingredients can be bought from one store?. {ingredients_generated}",
    output_key="prices_suggestion_generated",  # The result will be stored with this key.
)

print("✅ Prices Suggestion Agent defined.")
# Out:
# ✅ Prices Suggestion Agent defined.

# %% [markdown]
# **Sequential Agent created to get the recipe, the ingredients and stores suggestion agents in a sequential manner.
#
# System with three specialized agents:
#
# recipe_agent - gets the recipe
# ingredients_agent - gets the ingredients
# stores suggestion agent - gets the stores the ingredients are available at

# %%
root_agent = SequentialAgent(
    name="RecipeWithImagePipeline",
    sub_agents=[recipe_agent, ingredients_agent, store_suggestion_agent, price_estimation_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %% [markdown]
# ### Run your agent
#
# Now it's time to bring your agent to life and send it a query. To do this, you need a [`Runner`](https://google.github.io/adk-docs/runtime/), which is the central component within ADK that acts as the orchestrator. It manages the conversation, sends our messages to the agent, and handles its responses.
#
# **a. Create an `InMemoryRunner` and tell it to use our `root_agent`:**
# **Using run_debug to send out prompt and get the answer**

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Get me a sugar free recipe for pumpkin pie with ingredients and stores where the ingredients are available"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Get me a sugar free recipe for pumpkin pie with ingredients and stores where the ingredients are available
# recipe_assistant > Here is a sugar-free pumpkin pie recipe, sweetened naturally with dates and maple syrup, along with information on where to find the ingredients:
#
# **Sugar-Free Pumpkin Pie**
#
# This recipe offers a delicious and healthier alternative to traditional pumpkin pie, using natural sweeteners and real pumpkin.
#
# **Yields:** 6-8 servings
# **Prep time:** 45 minutes
# **Cook time:** 40-50 minutes
#
# **Ingredients:**
#
# *   1 unbaked 9-inch pie crust (homemade or store-bought, ensure it's sugar-free if store-bought)
# *   1/2 cup soft Medjool dates, pitted and chopped
# *   1/4 cup pure maple syrup
# *   1 1/2 cups pumpkin puree (ensure it's pure pumpkin, not pie filling)
# *   1 teaspoon cinnamon
# *   1 teaspoon ground ginger
# *   1/8 teaspoon ground nutmeg
# *   1/2 teaspoon salt
# *   3 large eggs
# *   1 cup milk (whole milk, almond milk, or coconut milk can be used)
# *   *Optional:* 1 teaspoon vanilla extract
#
# **For the Crust (if making homemade):**
#
# *   2 1/2 cups almond flour or oat flour
# *   1/2 cup soft Medjool dates, pitted and chopped
# *   4 tablespoons almond milk
#
# **Instructions:**
#
# 1.  **Prepare the Crust (if making homemade):** In a food processor, combine the crust ingredients until a dough-like consistency is formed. Press the dough evenly into the bottom and sides of a 9-inch pie pan. If using a store-bought crust, prepare it according to package instructions.
# 2.  **Preheat Oven:** Preheat your oven to 350°F (175°C).
# 3.  **Make the Filling:**
#     *   In a food processor, combine the pitted and chopped Medjool dates and maple syrup. Pulse until combined.
#     *   Add 1/2 cup of the pumpkin puree to the date mixture and process until smooth.
#     *   Add the remaining pumpkin puree, cinnamon, ginger, nutmeg, and salt. Process until well combined.
#     *   Add the eggs one at a time, processing until each is well incorporated. If using vanilla extract, add it now.
#     *   Gradually mix in the milk until the filling is thoroughly blended.
# 4.  **Assemble the Pie:** Pour the pumpkin pie filling into the prepared pie crust.
# 5.  **Bake:** Bake for 40-50 minutes, or until a knife inserted near the center comes out clean. You can also reduce the oven temperature to 350°F and bake for an additional 40-50 minutes if you initially preheated to 425°F.
# 6.  **Cool:** Let the pie cool completely on a wire rack for at least 2 hours. For best results, chill in the refrigerator overnight before serving.
#
# **Where to Find Ingredients:**
#
# *   **Dates (Medjool):** These can often be found in the dried fruit section of most major grocery stores, health food stores, and online retailers.
# *   **Maple Syrup:** Available in the syrup or baking aisle of most supermarkets.
# *   **Pumpkin Puree:** Look for canned, pure pumpkin puree in the baking aisle of grocery stores. Avoid "pumpkin pie filling," which often contains added sugars.
# *   **Spices (Cinnamon, Ginger, Nutmeg):** These are standard baking ingredients found in the spice aisle of any grocery store.
# *   **Eggs and Milk:** Readily available at any grocery store.
# *   **Almond Flour/Oat Flour:** Health food stores and the baking or natural foods section of larger supermarkets typically carry these.
# *   **Sugar-Free Baking Ingredients:** For specifically sugar-free pie crusts or alternative sweeteners like monk fruit or allulose, check specialty health food stores or online retailers like ChocZero and GOALZ Chocolates. Some online stores like Plantiful Kitchen also offer refined sugar-free baked goods and ingredients. Target also has a selection of "No Added Sugar" baking mixes.
#
# Enjoy your delicious and healthy sugar-free pumpkin pie!
# ingredients_assistant > Here are the ingredients for the sugar-free pumpkin pie recipe:
#
# **For the Pie Filling:**
#
# *   1 unbaked 9-inch pie crust (homemade or store-bought, ensure it's sugar-free if store-bought)
# *   1/2 cup soft Medjool dates, pitted and chopped
# *   1/4 cup pure maple syrup
# *   1 1/2 cups pumpkin puree (ensure it's pure pumpkin, not pie filling)
# *   1 teaspoon cinnamon
# *   1 teaspoon ground ginger
# *   1/8 teaspoon ground nutmeg
# *   1/2 teaspoon salt
# *   3 large eggs
# *   1 cup milk (whole milk, almond milk, or coconut milk can be used)
# *   *Optional:* 1 teaspoon vanilla extract
#
# **For the Crust (if making homemade):**
#
# *   2 1/2 cups almond flour or oat flour
# *   1/2 cup soft Medjool dates, pitted and chopped
# *   4 tablespoons almond milk
# ingredients_assistant > **Top 2 Stores for Ingredients:**
#
# 1.  **Major Grocery Stores (e.g., Kroger, Safeway, Publix, Walmart Supercenter):** These stores will carry the vast majority of your ingredients. You'll find pumpkin puree, spices, eggs, milk, maple syrup, and often a good selection of almond flour/oat flour in their baking or natural foods aisles. Some larger chains also carry Medjool dates in their dried fruit section.
# 2.  **Health Food Stores (e.g., Whole Foods Market, Sprouts):** These stores are excellent for sourcing Medjool dates, a wider variety of almond and oat flours, and potentially sugar-free pie crust options or alternative sweeteners if you choose to adapt the recipe further. They also have a comprehensive selection of all the other standard ingredients.
# price_estimation_assistant > I can help you with that! I will assume you are shopping at a major grocery store like Walmart, Kroger, or Safeway, as they carry most of these items. Prices can vary by location and brand, but here are my best estimates for the ingredients needed for the sugar-free pumpkin pie recipe:
#
# **For the Pie Filling:**
#
# *   **1 unbaked 9-inch pie crust:** (If store-bought and sugar-free) - **$3.50 - $5.00** (This can be tricky to find sugar-free. If you make it homemade, the cost will be from the crust ingredients below).
# *   **1/2 cup soft Medjool dates, pitted and chopped:** (A standard 8oz package yields more than this, so you'll have some left over) - **$5.00 - $7.00** per package
# *   **1/4 cup pure maple syrup:** (A 8oz bottle yields more than this) - **$6.00 - $9.00** per bottle
# *   **1 1/2 cups pumpkin puree:** (Two 15oz cans) - **$2.00 - $3.00** per can ($4.00 - $6.00 total)
# *   **1 teaspoon cinnamon:** (A standard spice jar yields much more) - **$3.00 - $5.00** per jar
# *   **1 teaspoon ground ginger:** (A standard spice jar yields much more) - **$3.00 - $5.00** per jar
# *   **1/8 teaspoon ground nutmeg:** (A standard spice jar yields much more) - **$3.00 - $5.00** per jar
# *   **1/2 teaspoon salt:** (A standard salt container yields much more) - **$1.00 - $2.00** per container
# *   **3 large eggs:** - **$3.00 - $5.00** per dozen
# *   **1 cup milk:** (Whole, almond, or coconut milk) - **$2.50 - $4.50** per half-gallon or quart depending on type
# *   **Optional: 1 teaspoon vanilla extract:** (A standard bottle yields much more) - **$4.00 - $6.00** per bottle
#
# **For the Crust (if making homemade):**
#
# *   **2 1/2 cups almond flour:** (A 16oz bag yields more than this) - **$7.00 - $10.00** per bag
# *   **1/2 cup soft Medjool dates, pitted and chopped:** (This is in addition to the filling, so you'd need another 1/2 cup. The 8oz package is likely sufficient for both if you measure carefully.) - Already accounted for above.
# *   **4 tablespoons almond milk:** (A small amount from the milk you buy for the filling) - Already accounted for above.
#
# **Estimated Total Cost (if making the crust homemade and assuming you'll have leftovers of spices, maple syrup, dates, flour, and vanilla):**
#
# *   **Minimum Estimate:** ~$40.00
# *   **Maximum Estimate:** ~$62.00
#
# **Important Notes on Pricing:**
#
# *   **Brand Variation:** Store brands are generally cheaper than name brands.
# *   **Package Sizes:** The prices are for standard package sizes. You will likely have leftover ingredients for future use, which makes the per-recipe cost lower.
# *   **Sales and Coupons:** Keep an eye out for sales and coupons, which can significantly reduce the overall cost.
# *   **Sugar-Free Crust:** Finding a pre-made, *truly* sugar-free pie crust can be difficult and expensive. Making it from scratch with almond flour is often more cost-effective and guarantees it's sugar-free.

# %% [markdown]
# 👉 Note that we are using the Python Runner directly in this notebook. You can also run agents using ADK command-line tools such as `adk run`, `adk web`, or `adk api_server`. To learn more, check out the documentation related to [runtime in ADK](https://google.github.io/adk-docs/runtime/).

# %% [markdown]
# **b. Now you can call the `.run_debug()` method to send our prompt and get an answer.**
#
# 👉 This method abstracts the process of session creation and maintenance and is used in prototyping. We'll explore "what sessions are and how to create them" on Day 3.

# %%
response = await runner.run_debug(
    "Give me a recipe for Apple Pie?  List the ingredients out separately and stores showing availability?"
)
# Out:
#  ### Continue session: debug_session_id
#
# User > Give me a recipe for Apple Pie?  List the ingredients out separately and stores showing availability?
# recipe_assistant > Here is a recipe for a sugar-free apple pie, using dates and maple syrup for sweetness, along with ingredient availability:
#
# **Sugar-Free Apple Pie**
#
# This recipe offers a comforting and naturally sweetened apple pie, perfect for those avoiding refined sugars.
#
# **Yields:** 6-8 servings
# **Prep time:** 30 minutes
# **Cook time:** 45-55 minutes
#
# **Ingredients:**
#
# **For the Filling:**
#
# *   6-8 medium apples (such as Honeycrisp, Fuji, or Gala), peeled, cored, and sliced
# *   1/2 cup soft Medjool dates, pitted and chopped
# *   1/4 cup pure maple syrup
# *   1 tablespoon lemon juice
# *   1 teaspoon ground cinnamon
# *   1/4 teaspoon ground nutmeg
# *   1/8 teaspoon ground allspice (optional)
# *   2 tablespoons cornstarch or arrowroot powder (for thickening)
# *   1 tablespoon unsalted butter or coconut oil (optional, for richness)
#
# **For the Crust (homemade, ensure it's sugar-free):**
#
# *   2 1/2 cups almond flour or oat flour
# *   1/2 cup soft Medjool dates, pitted and chopped
# *   4 tablespoons almond milk (or water)
# *   1/4 teaspoon salt
#
# **Instructions:**
#
# 1.  **Prepare the Crust (if making homemade):** In a food processor, combine the crust ingredients (almond flour/oat flour, pitted dates, almond milk, salt) until a dough forms. Press half of the dough evenly into the bottom and sides of a 9-inch pie dish. Set the remaining dough aside for the top crust.
# 2.  **Preheat Oven:** Preheat your oven to 375°F (190°C).
# 3.  **Prepare the Filling:** In a large bowl, combine the sliced apples, chopped dates, maple syrup, lemon juice, cinnamon, nutmeg, allspice (if using), and cornstarch/arrowroot powder. Toss gently to coat the apples evenly. If using butter or coconut oil, dot it over the apple mixture.
# 4.  **Assemble the Pie:** Pour the apple filling into the prepared bottom crust.
# 5.  **Create the Top Crust:** You can either roll out the remaining dough and place it as a solid top crust, cutting vents for steam, or cut it into strips for a lattice top. Crimp the edges to seal.
# 6.  **Bake:** Place the pie on a baking sheet (to catch any drips) and bake for 45-55 minutes, or until the crust is golden brown and the filling is bubbly. If the crust starts to brown too quickly, loosely tent the pie with aluminum foil.
# 7.  **Cool:** Let the pie cool on a wire rack for at least 2-3 hours before slicing and serving. This allows the filling to set properly.
#
# **Where to Find Ingredients:**
#
# *   **Apples:** Available at virtually all grocery stores, farmers' markets, and fruit stands.
# *   **Dates (Medjool):** Found in the dried fruit section of major grocery stores, health food stores, and online retailers.
# *   **Maple Syrup:** Located in the syrup or baking aisle of most supermarkets.
# *   **Lemon Juice:** Available in the produce section (fresh lemons) or in the baking/condiment aisle (bottled juice) of grocery stores.
# *   **Spices (Cinnamon, Nutmeg, Allspice):** Standard baking ingredients found in the spice aisle of any grocery store.
# *   **Cornstarch or Arrowroot Powder:** Available in the baking aisle of most supermarkets.
# *   **Butter or Coconut Oil:** Readily available at any grocery store.
# *   **Almond Flour/Oat Flour:** Health food stores and the baking or natural foods section of larger supermarkets typically carry these.
# *   **Almond Milk:** Available in the dairy or non-dairy milk section of grocery stores.
# *   **Salt:** Available in the baking or condiment aisle of any grocery store.
#
# For specific sugar-free pie crusts or alternative sweeteners if you wish to adapt further, check specialty health food stores or online retailers.
# ingredients_assistant > Here are the ingredients for the sugar-free apple pie:
#
# **For the Filling:**
#
# *   6-8 medium apples (such as Honeycrisp, Fuji, or Gala), peeled, cored, and sliced
# *   1/2 cup soft Medjool dates, pitted and chopped
# *   1/4 cup pure maple syrup
# *   1 tablespoon lemon juice
# *   1 teaspoon ground cinnamon
# *   1/4 teaspoon ground nutmeg
# *   1/8 teaspoon ground allspice (optional)
# *   2 tablespoons cornstarch or arrowroot powder (for thickening)
# *   1 tablespoon unsalted butter or coconut oil (optional, for richness)
#
# **For the Crust:**
#
# *   2 1/2 cups almond flour or oat flour
# *   1/2 cup soft Medjool dates, pitted and chopped
# *   4 tablespoons almond milk (or water)
# *   1/4 teaspoon salt
#
# **Stores Showing Availability:**
#
# 1.  **Major Grocery Stores (e.g., Walmart, Kroger, Safeway, Target):**
#     *   **Apples:** Produce section.
#     *   **Medjool Dates:** Dried fruit aisle.
#     *   **Maple Syrup:** Syrup or baking aisle.
#     *   **Lemon Juice:** Produce section (fresh lemons) or baking aisle (bottled).
#     *   **Spices (Cinnamon, Nutmeg, Allspice):** Spice aisle.
#     *   **Cornstarch or Arrowroot Powder:** Baking aisle.
#     *   **Butter or Coconut Oil:** Dairy or baking aisle.
#     *   **Almond Flour/Oat Flour:** Baking aisle or natural foods section.
#     *   **Almond Milk:** Dairy or non-dairy milk section.
#     *   **Salt:** Baking or condiment aisle.
#
# 2.  **Health Food Stores (e.g., Whole Foods Market, Sprouts):**
#     *   These stores will have a comprehensive selection of all the above ingredients, including a wider variety of almond and oat flours, and potentially specific brands of sugar-free pie crusts or alternative sweeteners if you wish to adapt further.
#
# 3.  **Online Retailers (e.g., Amazon, Thrive Market):**
#     *   You can find all these ingredients online, often with a good selection of specialty items like different types of almond flour or sugar-free baking mixes.
# ingredients_assistant > I've completed the requests for the sugar-free apple pie recipe and its ingredients, along with the stores where they can be purchased. I've also provided the sugar-free pumpkin pie recipe and its ingredient availability as requested earlier.
#
# Please let me know if you have any further requests or need a summary of the information provided!
# price_estimation_assistant > I can help you with that! Here is a recipe for a classic apple pie, along with a breakdown of the ingredients and where you can find them, assuming you're shopping at a **Major Grocery Store (like Walmart, Kroger, Safeway, or Target)**. Prices are estimates and can vary by location and brand.
#
# ---
#
# **Classic Apple Pie**
#
# This recipe focuses on a traditional apple pie, which typically uses refined sugar. If you're looking for a sugar-free version, please refer to the previous sugar-free apple pie recipe.
#
# **Yields:** 8 servings
# **Prep time:** 30 minutes
# **Cook time:** 50-60 minutes
#
# **Ingredients:**
#
# **For the Filling:**
#
# *   6-7 medium apples (e.g., Granny Smith, Honeycrisp, Gala), peeled, cored, and sliced about 1/4-inch thick
# *   3/4 cup granulated sugar (or a mix of granulated and brown sugar)
# *   2 tablespoons all-purpose flour (or cornstarch)
# *   1 teaspoon ground cinnamon
# *   1/4 teaspoon ground nutmeg
# *   1/8 teaspoon ground allspice (optional)
# *   1 tablespoon lemon juice
# *   2 tablespoons unsalted butter, cut into small pieces
#
# **For the Crust:**
#
# *   2 1/2 cups all-purpose flour
# *   1 teaspoon salt
# *   1 cup (2 sticks) cold unsalted butter, cut into cubes
# *   1/2 cup ice water (plus more if needed)
#
# **Instructions:**
#
# 1.  **Make the Crust:**
#     *   In a large bowl, whisk together the flour and salt.
#     *   Cut in the cold butter using a pastry blender or your fingertips until the mixture resembles coarse crumbs with some pea-sized pieces of butter remaining.
#     *   Gradually add the ice water, 1 tablespoon at a time, mixing until the dough just comes together. Be careful not to overmix.
#     *   Divide the dough in half, flatten each half into a disk, wrap in plastic wrap, and refrigerate for at least 30 minutes.
# 2.  **Preheat Oven:** Preheat your oven to 425°F (220°C).
# 3.  **Prepare the Filling:**
#     *   In a large bowl, combine the sliced apples, sugar, flour (or cornstarch), cinnamon, nutmeg, allspice (if using), and lemon juice. Toss gently to coat the apples evenly.
# 4.  **Assemble the Pie:**
#     *   On a lightly floured surface, roll out one disk of dough into a 12-inch circle. Carefully transfer it to a 9-inch pie plate. Trim and crimp the edges.
#     *   Pour the apple filling into the crust. Dot the top with the small pieces of butter.
#     *   Roll out the second disk of dough. You can either place it as a solid top crust (cutting vents for steam) or cut it into strips for a lattice top. Crimp the edges to seal.
# 5.  **Bake:**
#     *   Place the pie on a baking sheet (to catch any drips). Bake at 425°F (220°C) for 15 minutes.
#     *   Reduce the oven temperature to 375°F (190°C) and continue baking for another 35-45 minutes, or until the crust is golden brown and the filling is bubbly. If the crust starts to brown too quickly, loosely tent the pie with aluminum foil.
# 6.  **Cool:** Let the pie cool on a wire rack for at least 2-3 hours before slicing and serving. This allows the filling to set properly.
#
# ---
#
# **Ingredients and Where to Find Them (Major Grocery Store):**
#
# **For the Filling:**
#
# *   **6-7 medium apples:**
#     *   **Availability:** Produce section.
#     *   **Estimated Price:** $1.00 - $2.00 per pound (you'll likely need 3-4 pounds, so $3.00 - $8.00)
# *   **3/4 cup granulated sugar:**
#     *   **Availability:** Baking aisle.
#     *   **Estimated Price:** $3.00 - $5.00 for a 4lb bag (you'll use a small portion)
# *   **2 tablespoons all-purpose flour:**
#     *   **Availability:** Baking aisle.
#     *   **Estimated Price:** $3.00 - $5.00 for a 5lb bag (you'll use a small portion)
# *   **1 teaspoon ground cinnamon:**
#     *   **Availability:** Spice aisle.
#     *   **Estimated Price:** $3.00 - $5.00 per jar (you'll use a small portion)
# *   **1/4 teaspoon ground nutmeg:**
#     *   **Availability:** Spice aisle.
#     *   **Estimated Price:** $3.00 - $5.00 per jar (you'll use a small portion)
# *   **1/8 teaspoon ground allspice (optional):**
#     *   **Availability:** Spice aisle.
#     *   **Estimated Price:** $3.00 - $5.00 per jar (you'll use a small portion)
# *   **1 tablespoon lemon juice:**
#     *   **Availability:** Produce section (fresh lemons) or baking/condiment aisle (bottled).
#     *   **Estimated Price:** $0.50 - $1.00 for a lemon, or $2.00 - $4.00 for bottled juice.
# *   **2 tablespoons unsalted butter:**
#     *   **Availability:** Dairy aisle.
#     *   **Estimated Price:** $4.00 - $6.00 per pound (you'll use a small portion)
#
# **For the Crust:**
#
# *   **2 1/2 cups all-purpose flour:**
#     *   **Availability:** Baking aisle.
#     *   **Estimated Price:** $3.00 - $5.00 for a 5lb bag (you'll use about half)
# *   **1 teaspoon salt:**
#     *   **Availability:** Baking or condiment aisle.
#     *   **Estimated Price:** $1.00 - $2.00 per container (you'll use a small portion)
# *   **1 cup (2 sticks) cold unsalted butter:**
#     *   **Availability:** Dairy aisle.
#     *   **Estimated Price:** $4.00 - $6.00 per pound (you'll use the whole pound)
# *   **1/2 cup ice water:**
#     *   **Availability:** Tap water (free!).
#
# **Estimated Total Cost (if buying full packages of ingredients and making crust from scratch):**
#
# *   **Minimum Estimate:** ~$27.50
# *   **Maximum Estimate:** ~$46.00
#
# **Note:** This estimate assumes you are buying standard package sizes for ingredients like flour, sugar, spices, and butter, and you will have leftovers for future baking. The apples and butter will likely be the most significant costs for this specific recipe.

# %% [markdown]
# You can see a summary of ADK and its available languages in the response.
#
# ### How does it work?
#
# The agent performed a Google Search to get the latest information about ADK, and it knew to use this tool because:
#
# 1. The agent inspects and is aware of which tools it has available to use.
# 2. The agent's instructions specify the use of the search tool to get current information or if it is unsure of an answer.
#
# The best way to see the full, detailed trace of the agent's thoughts and actions is in the **ADK web UI**, which we'll set up later in this notebook.
#
# And we'll cover more detailed workflows for logging and observability later in the course.

# %% [markdown]
# ### 🚀 Checking out other sugar free recipes

# %%
response = await runner.run_debug("What's the recipe for Indian sweet Gulab Jamun?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the recipe for Indian sweet Gulab Jamun?
# recipe_assistant > Here's a recipe for Gulab Jamun, a popular Indian sweet, along with ingredient information:
#
# **Gulab Jamun Recipe**
#
# Gulab Jamun are soft, spongy milk-solid-based balls, deep-fried and soaked in a fragrant sugar syrup. They are a quintessential Indian dessert, often served during festivals and celebrations. This recipe uses milk powder, which is more readily available than traditional khoya (milk solids).
#
# **Yields:** Approximately 20-24 gulab jamuns
# **Prep time:** 30 minutes (+ 10 minutes resting)
# **Cook time:** 20-30 minutes (frying) + 2-3 hours (soaking)
#
# **Ingredients:**
#
# **For the Gulab Jamun Balls:**
#
# *   1 ½ cups milk powder (whole milk powder recommended for best results)
# *   ½ cup all-purpose flour (maida)
# *   ½ teaspoon baking powder
# *   ¼ teaspoon salt (optional, some recipes omit)
# *   2 tablespoons ghee (clarified butter), melted, plus more for greasing fingers
# *   2-4 tablespoons milk (lukewarm), as needed to form dough or 1 cup whipping cream
# *   1 tablespoon natural yogurt or ¼ teaspoon lemon juice (acts as a binder)
# *   *Optional additions:* Chopped almonds, pistachios, or golden raisins
#
# **For the Sugar Syrup:**
#
# *   1 ¼ cups white sugar or 2 cups sugar or 3 cups sugar
# *   7 fluid ounces water or 1.5 cups water or 2 cups water or 4 cups water
# *   2-4 green cardamom pods, lightly crushed
# *   A few drops of rose water
# *   *Optional:* ¼ teaspoon saffron strands, soaked in 2 tablespoons warm water
#
# **For Frying:**
#
# *   Vegetable oil or ghee for deep frying (about 3-4 cups)
#
# **Instructions:**
#
# 1.  **Prepare the Dough:**
#     *   In a large bowl, combine the milk powder, all-purpose flour, baking powder, and salt (if using). Mix well.
#     *   Add the melted ghee and mix until the flour is moist.
#     *   In a small bowl, combine the yogurt/lemon juice with 2 tablespoons of milk. Add this to the dry ingredients.
#     *   Gradually add more milk (or whipping cream) as needed, mixing with a spoon or your fingers to form a soft, smooth dough. Do not knead vigorously; just bring it together.
#     *   Cover the dough and let it rest for about 10-20 minutes.
#
# 2.  **Prepare the Sugar Syrup:**
#     *   While the dough rests, combine the sugar, water, and crushed cardamom pods in a saucepan.
#     *   Heat over medium flame, stirring until the sugar dissolves completely.
#     *   Bring to a boil and simmer for about 5-7 minutes, or until the syrup becomes slightly sticky. To check for stickiness, take a ¼ teaspoon of syrup, cool it slightly, and rub it between your thumb and forefinger; it should feel sticky and slightly stringy but not form a one-string consistency.
#     *   Turn off the heat. Stir in the rose water and saffron (if using). Keep the syrup warm.
#
# 3.  **Shape the Gulab Jamuns:**
#     *   Grease your palms lightly with ghee.
#     *   Take small portions of the dough and gently roll them between your palms to form smooth, crack-free balls (about 1 inch in diameter). Ensure there are no cracks, as this can cause them to break during frying.
#
# 4.  **Fry the Gulab Jamuns:**
#     *   Heat the oil or ghee in a deep pan or wok over medium heat. The oil should be medium hot, not too hot. To test, drop a tiny piece of dough; it should rise slowly with bubbles. If it rises too quickly or browns fast, the oil is too hot; let it cool slightly.
#     *   Gently slide the dough balls into the oil, in batches, ensuring not to overcrowd the pan.
#     *   Fry on medium heat for 1-2 minutes, then reduce the flame to low or medium-low.
#     *   Keep stirring gently and fry until the gulab jamuns turn an even, deep golden brown color. This typically takes about 5-7 minutes per batch.
#     *   Remove the fried gulab jamuns with a slotted spoon and drain them on paper towels.
#
# 5.  **Soak in Syrup:**
#     *   Immediately transfer the warm, fried gulab jamuns into the warm sugar syrup.
#     *   Let them soak for at least 2-3 hours, or preferably overnight, to absorb the syrup and become soft and spongy.
#
# 6.  **Serve:**
#     *   Serve the gulab jamun warm or at room temperature. They can be garnished with chopped pistachios or almonds.
#
# **Where to Find Ingredients:**
#
# *   **Milk Powder:** Available in the dairy or baking aisle of most major grocery stores. It's also readily available in Indian or Asian grocery stores.
# *   **All-Purpose Flour (Maida):** Found in the baking aisle of any grocery store.
# *   **Baking Powder, Salt, Sugar, Water:** Standard pantry staples available at all grocery stores.
# *   **Ghee (Clarified Butter):** Available in the international foods aisle of many larger supermarkets, and commonly found in Indian or Middle Eastern grocery stores. It can also be made at home from butter.
# *   **Milk, Yogurt, Lemon Juice:** Readily available at any grocery store.
# *   **Cardamom Pods, Rose Water, Saffron:** These can be found in the spice aisle of larger supermarkets or in the international foods section. Indian grocery stores are an excellent source for these items.
# *   **Vegetable Oil:** Available in the cooking oil aisle of all grocery stores.
# *   **Nuts (Pistachios, Almonds):** Found in the baking or snack aisle of grocery stores. Indian grocery stores often have a good selection of nuts.
# *   **Pre-made Gulab Jamun Mix:** Many Indian grocery stores and some larger supermarkets carry pre-made gulab jamun mixes, which can simplify the process further.
#
# Enjoy making and savoring this delicious Indian sweet!
# ingredients_assistant > Here are the ingredients for Gulab Jamun:
#
# **For the Gulab Jamun Balls:**
#
# *   1 ½ cups milk powder
# *   ½ cup all-purpose flour (maida)
# *   ½ teaspoon baking powder
# *   ¼ teaspoon salt (optional)
# *   2 tablespoons ghee, melted, plus more for greasing fingers
# *   2-4 tablespoons milk (lukewarm), as needed to form dough or 1 cup whipping cream
# *   1 tablespoon natural yogurt or ¼ teaspoon lemon juice
# *   *Optional additions:* Chopped almonds, pistachios, or golden raisins
#
# **For the Sugar Syrup:**
#
# *   1 ¼ cups white sugar (or 2 cups, or 3 cups)
# *   7 fluid ounces water (or 1.5 cups, or 2 cups, or 4 cups)
# *   2-4 green cardamom pods, lightly crushed
# *   A few drops of rose water
# *   *Optional:* ¼ teaspoon saffron strands, soaked in 2 tablespoons warm water
#
# **For Frying:**
#
# *   Vegetable oil or ghee for deep frying (about 3-4 cups)
# ingredients_assistant > Top 2 Stores for Gulab Jamun Ingredients:
#
# 1.  **Indian Grocery Stores:** These stores are your best bet for authentic ingredients like milk powder, ghee, cardamom pods, rose water, and saffron. They will also likely have a good selection of nuts.
# 2.  **Major Grocery Stores (e.g., Walmart, Kroger, Safeway):** You can find most of the basic ingredients here, including milk powder, all-purpose flour, baking powder, salt, sugar, vegetable oil, milk, yogurt, lemon juice, and sometimes ghee in the international aisle. Nuts are also widely available.
# price_estimation_assistant > I can help you find the prices for the ingredients for Gulab Jamun at a **Major Grocery Store (like Walmart, Kroger, Safeway, or Target)**. Please note that prices can vary by location and brand.
#
# Here are the estimated prices for the ingredients, assuming you are buying standard package sizes and will have leftovers for future use:
#
# **For the Gulab Jamun Balls:**
#
# *   **1 ½ cups milk powder:** (A standard 8oz or 11oz container yields more than this) - **$3.00 - $6.00** per container.
# *   **½ cup all-purpose flour (maida):** (A 5lb bag yields much more) - **$3.00 - $5.00** per bag.
# *   **½ teaspoon baking powder:** (A standard 8oz or 16oz container yields much more) - **$2.00 - $3.00** per container.
# *   **¼ teaspoon salt (optional):** (A standard container yields much more) - **$1.00 - $2.00** per container.
# *   **2 tablespoons ghee, melted, plus more for greasing fingers:** (A standard 8oz or 16oz jar yields much more) - **$5.00 - $9.00** per jar.
# *   **2-4 tablespoons milk (lukewarm):** (A gallon or half-gallon carton yields much more) - **$2.50 - $4.50** per carton.
# *   **1 tablespoon natural yogurt or ¼ teaspoon lemon juice:** (Yogurt is typically sold in 6oz or 32oz containers, lemon juice in bottles) - Yogurt: **$1.00 - $2.00** for a small container. Lemon juice: **$2.00 - $4.00** per bottle.
# *   **Optional additions: Chopped almonds, pistachios, or golden raisins:**
#     *   Almonds (a small bag): **$4.00 - $7.00**
#     *   Pistachios (a small bag): **$5.00 - $8.00**
#     *   Golden raisins (a small box): **$3.00 - $5.00**
#
# **For the Sugar Syrup:**
#
# *   **1 ¼ cups white sugar:** (A 4lb bag yields much more) - **$3.00 - $5.00** per bag.
# *   **7 fluid ounces water:** (Tap water is free!)
# *   **2-4 green cardamom pods:** (A small jar or packet yields many more) - **$4.00 - $7.00** per jar/packet.
# *   **A few drops of rose water:** (A small bottle yields many more) - **$3.00 - $5.00** per bottle.
# *   **Optional: ¼ teaspoon saffron strands:** (A small tin or packet yields much more) - **$8.00 - $15.00+** per tin/packet (saffron is expensive).
#
# **For Frying:**
#
# *   **Vegetable oil or ghee for deep frying (about 3-4 cups):**
#     *   Vegetable oil (a large 48oz or 1 gallon bottle yields much more) - **$4.00 - $8.00** per bottle.
#     *   Ghee: (See above for ghee price).
#
# **Estimated Total Cost (assuming you buy all ingredients in standard package sizes and will have leftovers):**
#
# *   **Minimum Estimate (without optional nuts/saffron):** ~$32.00
# *   **Maximum Estimate (with pistachios and saffron):** ~$68.00+
#
# **Important Considerations:**
#
# *   **Indian Grocery Stores:** For items like ghee, cardamom, rose water, saffron, and milk powder, visiting an Indian grocery store might offer better prices and quality.
# *   **Leftovers:** You will have significant leftovers of most ingredients, making the cost per batch of Gulab Jamun much lower over time.
# *   **Brand Choice:** Store brands are generally more affordable than name brands.
# *   **Sales and Coupons:** Keep an eye out for sales and coupons to reduce the overall cost.

# %%
response = await runner.run_debug("What's the recipe for Indian sweet Gulab Jamun not using milk powder?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the recipe for Indian sweet Gulab Jamun not using milk powder?
# recipe_assistant > Here's a recipe for Gulab Jamun made without milk powder, using khoya (reduced milk solids) or ricotta cheese as the base. This method often results in a richer, more traditional flavor.
#
# **Traditional Gulab Jamun (using Khoya or Ricotta)**
#
# This recipe uses khoya, which is essentially evaporated milk solids. If khoya is not readily available, good quality whole milk ricotta cheese can be used as a substitute, though the texture and flavor will be slightly different.
#
# **Yields:** Approximately 20-24 gulab jamuns
# **Prep time:** 30 minutes
# **Cook time:** 20-30 minutes (frying) + 2-3 hours (soaking)
#
# **Ingredients:**
#
# **For the Gulab Jamun Balls:**
#
# *   1 cup khoya (mawa), crumbled or grated (see notes below for ricotta substitute)
# *   ¼ cup all-purpose flour (maida)
# *   1 tablespoon all-purpose flour (maida) for dusting
# *   ¼ teaspoon baking soda (not baking powder)
# *   1 tablespoon ghee, melted, plus more for greasing fingers
# *   *Optional additions:* 1-2 tablespoons chopped almonds or pistachios, a pinch of ground cardamom
#
# **For the Sugar Syrup:**
#
# *   1 ¼ cups white sugar (or 2 cups, or 3 cups)
# *   7 fluid ounces water (or 1.5 cups, or 2 cups, or 4 cups)
# *   2-4 green cardamom pods, lightly crushed
# *   A few drops of rose water
# *   *Optional:* ¼ teaspoon saffron strands, soaked in 2 tablespoons warm water
#
# **For Frying:**
#
# *   Vegetable oil or ghee for deep frying (about 3-4 cups)
#
# **Instructions:**
#
# 1.  **Prepare the Khoya/Ricotta:**
#     *   **If using Khoya:** Ensure the khoya is at room temperature. Crumble or grate it finely.
#     *   **If using Ricotta:** Drain the ricotta cheese very well to remove as much moisture as possible. You can do this by placing it in a fine-mesh sieve lined with cheesecloth or a clean kitchen towel over a bowl for at least 30 minutes, or by gently pressing out the excess liquid. You want a firm, crumbly texture, not wet.
#
# 2.  **Prepare the Dough:**
#     *   In a bowl, combine the crumbled khoya (or well-drained ricotta), ¼ cup all-purpose flour, melted ghee, and baking soda.
#     *   Mix gently with your fingers until it just comes together to form a soft dough. Do not overmix or knead, as this can make the gulab jamuns tough.
#     *   If the dough is too sticky, add a little of the extra flour for dusting. If it seems too dry, add a teaspoon of milk or water.
#
# 3.  **Prepare the Sugar Syrup:**
#     *   Combine the sugar, water, and crushed cardamom pods in a saucepan.
#     *   Heat over medium flame, stirring until the sugar dissolves completely.
#     *   Bring to a boil and simmer for about 5-7 minutes, or until the syrup becomes slightly sticky. To check for stickiness, take a ¼ teaspoon of syrup, cool it slightly, and rub it between your thumb and forefinger; it should feel sticky and slightly stringy but not form a one-string consistency.
#     *   Turn off the heat. Stir in the rose water and saffron (if using). Keep the syrup warm.
#
# 4.  **Shape the Gulab Jamuns:**
#     *   Grease your palms lightly with ghee.
#     *   Take small portions of the dough and gently roll them between your palms to form smooth, crack-free balls (about 1 inch in diameter). Ensure there are no cracks.
#     *   If adding nuts or cardamom, gently press a small amount into the center of a dough ball before shaping it into a smooth sphere.
#
# 5.  **Fry the Gulab Jamuns:**
#     *   Heat the oil or ghee in a deep pan or wok over medium heat. The oil should be medium hot, not too hot. To test, drop a tiny piece of dough; it should rise slowly with bubbles. If it rises too quickly or browns fast, the oil is too hot; let it cool slightly.
#     *   Gently slide the dough balls into the oil, in batches, ensuring not to overcrowd the pan.
#     *   Fry on medium heat for 1-2 minutes, then reduce the flame to low or medium-low.
#     *   Keep stirring gently and fry until the gulab jamuns turn an even, deep golden brown color. This typically takes about 7-10 minutes per batch, as khoya/ricotta takes longer to cook than milk powder.
#     *   Remove the fried gulab jamuns with a slotted spoon and drain them on paper towels.
#
# 6.  **Soak in Syrup:**
#     *   Immediately transfer the warm, fried gulab jamuns into the warm sugar syrup.
#     *   Let them soak for at least 2-3 hours, or preferably overnight, to absorb the syrup and become soft and spongy.
#
# 7.  **Serve:**
#     *   Serve the gulab jamun warm or at room temperature. Garnish with chopped pistachios or almonds if desired.
#
# **Notes on Khoya and Ricotta:**
#
# *   **Khoya (Mawa):** This is the most traditional ingredient. You can buy it from Indian grocery stores. If you want to make khoya at home, it involves simmering milk for a long time until it reduces to solids, which is a time-consuming process.
# *   **Ricotta Cheese Substitute:** Use whole milk ricotta cheese and ensure it is very well-drained. The texture of the gulab jamun will be slightly softer and perhaps a bit more delicate. The flavor will be good, but not exactly the same as khoya-based ones.
#
# **Where to Find Ingredients:**
#
# *   **Khoya (Mawa):** Primarily found in Indian or South Asian grocery stores.
# *   **Ricotta Cheese (Whole Milk):** Available in the dairy section of most major grocery stores.
# *   **All-Purpose Flour (Maida):** Found in the baking aisle of any grocery store.
# *   **Baking Soda:** Available in the baking aisle of all grocery stores.
# *   **Ghee (Clarified Butter):** Available in the international foods aisle of many larger supermarkets, and commonly found in Indian or Middle Eastern grocery stores.
# *   **Milk, Yogurt, Lemon Juice:** Readily available at any grocery store.
# *   **Sugar, Water:** Standard pantry staples available at all grocery stores.
# *   **Cardamom Pods, Rose Water, Saffron:** Found in the spice aisle of larger supermarkets or in the international foods section. Indian grocery stores are an excellent source for these.
# *   **Vegetable Oil:** Available in the cooking oil aisle of all grocery stores.
# *   **Nuts (Pistachios, Almonds):** Found in the baking or snack aisle of grocery stores. Indian grocery stores often have a good selection of nuts.
# ingredients_assistant > Here are the ingredients for Traditional Gulab Jamun (using Khoya or Ricotta):
#
# **For the Gulab Jamun Balls:**
#
# *   1 cup khoya (mawa), crumbled or grated
# *   ¼ cup all-purpose flour (maida)
# *   1 tablespoon all-purpose flour (maida) for dusting
# *   ¼ teaspoon baking soda (not baking powder)
# *   1 tablespoon ghee, melted, plus more for greasing fingers
# *   *Optional additions:* 1-2 tablespoons chopped almonds or pistachios, a pinch of ground cardamom
#
# **For the Sugar Syrup:**
#
# *   1 ¼ cups white sugar (or 2 cups, or 3 cups)
# *   7 fluid ounces water (or 1.5 cups, or 2 cups, or 4 cups)
# *   2-4 green cardamom pods, lightly crushed
# *   A few drops of rose water
# *   *Optional:* ¼ teaspoon saffron strands, soaked in 2 tablespoons warm water
#
# **For Frying:**
#
# *   Vegetable oil or ghee for deep frying (about 3-4 cups)
# ingredients_assistant > As per your instruction, I will continue processing previous requests as instructed. Since there are no further pending requests in this turn, I will exit.
#
# **Summary of Information Provided:**
#
# I have provided recipes and ingredient availability for:
#
# *   **Traditional Gulab Jamun (using Khoya or Ricotta)**
# *   **Sugar-Free Pumpkin Pie**
# *   **Sugar-Free Apple Pie**
# *   **Classic Apple Pie**
#
# For each recipe, I have:
# *   Listed the ingredients separately.
# *   Identified the top 2 stores where the ingredients can be purchased.
# *   (For some recipes, at the request of the `price_estimation_assistant`) Provided estimated prices for ingredients at major grocery stores.
#
# Please let me know if you have any further requests!
# price_estimation_assistant > I can help you find the prices for the ingredients for Traditional Gulab Jamun (using Khoya or Ricotta) at a **Major Grocery Store (like Walmart, Kroger, Safeway, or Target)**. Please note that prices can vary by location and brand, and some ingredients might be more easily found at an Indian grocery store for better quality or price.
#
# Here are the estimated prices for the ingredients, assuming you are buying standard package sizes and will have leftovers for future use:
#
# **For the Gulab Jamun Balls:**
#
# *   **1 cup khoya (mawa), crumbled or grated:**
#     *   **Availability:** Primarily found at Indian grocery stores. Major supermarkets may carry it in their international aisle, but selection can be limited.
#     *   **Estimated Price:** **$4.00 - $7.00** per 7-8 oz package. (If using the ricotta substitute, see below).
# *   **¼ cup all-purpose flour (maida):**
#     *   **Availability:** Baking aisle.
#     *   **Estimated Price:** $3.00 - $5.00 for a 5lb bag (you'll use a very small portion).
# *   **1 tablespoon all-purpose flour (maida) for dusting:**
#     *   **Availability:** Baking aisle. (Covered by the above).
# *   **¼ teaspoon baking soda:**
#     *   **Availability:** Baking aisle.
#     *   **Estimated Price:** $2.00 - $3.00 for a standard container (you'll use a tiny amount).
# *   **1 tablespoon ghee, melted, plus more for greasing fingers:**
#     *   **Availability:** International aisle of larger supermarkets, or Indian grocery stores.
#     *   **Estimated Price:** $5.00 - $9.00 for an 8oz or 16oz jar.
# *   **Optional additions: 1-2 tablespoons chopped almonds or pistachios, a pinch of ground cardamom:**
#     *   Almonds (small bag): **$4.00 - $7.00**
#     *   Pistachios (small bag): **$5.00 - $8.00**
#     *   Ground cardamom (small jar): **$4.00 - $7.00**
#
# **If using Ricotta Cheese substitute:**
#
# *   **1 cup whole milk ricotta cheese:**
#     *   **Availability:** Dairy aisle.
#     *   **Estimated Price:** $3.00 - $5.00 per 15oz container. (You'll use a portion of this).
#
# **For the Sugar Syrup:**
#
# *   **1 ¼ cups white sugar:**
#     *   **Availability:** Baking aisle.
#     *   **Estimated Price:** $3.00 - $5.00 for a 4lb bag (you'll use a small portion).
# *   **7 fluid ounces water:**
#     *   **Availability:** Tap water (free!).
# *   **2-4 green cardamom pods:**
#     *   **Availability:** Spice aisle or international aisle.
#     *   **Estimated Price:** $4.00 - $7.00 per small jar/packet (you'll use a few pods).
# *   **A few drops of rose water:**
#     *   **Availability:** Spice aisle or international aisle.
#     *   **Estimated Price:** $3.00 - $5.00 per small bottle (you'll use a few drops).
# *   **Optional: ¼ teaspoon saffron strands:**
#     *   **Availability:** Spice aisle or international aisle.
#     *   **Estimated Price:** $8.00 - $15.00+ per small tin/packet (saffron is very expensive).
#
# **For Frying:**
#
# *   **Vegetable oil or ghee for deep frying (about 3-4 cups):**
#     *   Vegetable oil (large bottle): **$4.00 - $8.00**
#     *   Ghee (if not used for the dough): **$5.00 - $9.00**
#
# **Estimated Total Cost (assuming you buy all ingredients in standard package sizes and will have leftovers):**
#
# *   **Using Khoya (without optional nuts/saffron):** ~$29.00 - $50.00
# *   **Using Ricotta (without optional nuts/saffron):** ~$26.00 - $47.00
#
# **Important Notes:**
#
# *   **Khoya Availability:** The biggest variable here is the price and availability of khoya. If you have an Indian grocery store nearby, it's highly recommended for the best prices and quality of khoya, ghee, cardamom, and rose water.
# *   **Leftovers:** As with most recipes, you will have substantial leftovers of flour, sugar, baking soda, oil, and potentially ghee and spices, making the cost per batch of Gulab Jamun lower over time.
# *   **Brand Variation:** Store brands are generally more affordable.
# *   **Sales:** Keep an eye out for sales, especially on ghee and cooking oil.

# %% [markdown]
# ---
#
# ## 💻 Section 3: Try the ADK Web Interface
#
# ### Overview
#
# ADK includes a built-in web interface for interactively chatting with, testing, and debugging your agents.
#
# <img width="1200" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/adk-web-ui.gif" alt="ADK Web UI" />
#
# To use the ADK web UI, you'll need to create an agent with Python files using the `adk create` command.
#
# Run the command below to generate a `sample-agent` folder that contains all the necessary files, including `agent.py` for your code, an `.env` file with your API key pre-configured, and an `__init__.py` file:

# %%
# !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in /kaggle/working/sample-agent:
# - .env
# - __init__.py
# - agent.py

# %% [markdown]
# Get your custom URL to access the ADK web UI in the Kaggle Notebooks environment:

# %%
url_prefix = get_adk_proxy_url()
# Out:
#     <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
#         <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
#             <strong>⚠️ IMPORTANT: Action Required</strong>
#         </div>
#         <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
#             The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
#             <ol style="margin-top: 10px; padding-left: 20px;">
#                 <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
#                 <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
#                 <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
#             </ol>
#             <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
#         </div>
#         <a href='https://kkb-production.jupyter-proxy.kaggle.net/k/281529963/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..6gYOuXW48D2rQH1SFMmsVw.X7vBD-QBrgg96HazkFNMI9MZV7RlL6yeBT-_eJibqeqXo8whB6_DSIP0pDfN9gN4LLEjwrXTsMh00dCWmHb8BVCCxzrx_P-vr8Xio3-EPtdB5fz8sxMfoQ0IG3AzP3ZuJaty3VOQqJ2xWKqYfj-5Bi3wKKjl-J8gtjkvAoxK7yMJSiaypv7Te0ebq8DcuWW_GzXfdYavgOWwfXS2D-vmFcNKqXf9u8HaFKlWjbV8VbBo5hTNKrGACY-U4hJxXPYJ.480vnaoLuHEBXFV1GZVoVw/proxy/proxy/8000' target='_blank' style="
#             display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
#             text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
#             Open ADK Web UI (after running cell below) ↗
#         </a>
#     </div>

# %% [markdown]
# Now we can run ADK web:

# %%
# !adk web --url_prefix {url_prefix}
# Out:
# /usr/local/lib/python3.11/dist-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /usr/local/lib/python3.11/dist-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [93]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)

# %% [markdown]
# Now you can access the ADK dev UI using the link above.
#
# Once you open the link, you'll see the ADK web interface where you can ask your ADK agent questions.
#
# Note: This sample agent does not have any tools enabled (like Google Search). It is a basic agent designed specifically to let you explore the UI features.
#
# ‼️ **IMPORTANT: DO NOT SHARE THE PROXY LINK** with anyone - treat it as sensitive data as it contains your authentication token in the URL.
