# %% [markdown]
# # Agents Intensive - Capstone Project - Monisha Shah
#
# **Kaggle 5-day Agents course!**
#
# Creating agents to get the recipes for sugar free deserts along with Ingredients.
#
# Using a Sequential Agents to retrieve the recipe for the desert and where to buy the ingredients from.

# %% [markdown]
# ### Install dependencies google agent development kit library
#
# The Kaggle Notebooks environment includes a pre-installed version of the [google-adk](https://google.github.io/adk-docs/) library for Python and its required dependencies, so you don't need to install additional packages in this notebook.
#
# To install and use ADK in your own Python development environment outside of this course, you can do so by running:
#
# ```
# pip install google-adk
# ```

# %% [markdown]
# ### Configure your Gemini API Key
#
# This notebook uses the [Gemini API](https://ai.google.dev/gemini-api/docs), which requires authentication.
#
# **1. Get your API key**
#
# If you don't have one already, create an [API key in Google AI Studio](https://aistudio.google.com/app/api-keys).
#
# **2. Add the key to Kaggle Secrets**
#
# Next, you will need to add your API key to your Kaggle Notebook as a Kaggle User Secret.
#
# 1. In the top menu bar of the notebook editor, select `Add-ons` then `Secrets`.
# 2. Create a new secret with the label `GOOGLE_API_KEY`.
# 3. Paste your API key into the "Value" field and click "Save".
# 4. Ensure that the checkbox next to `GOOGLE_API_KEY` is selected so that the secret is attached to the notebook.
#
# **3. Authenticate in the notebook**
#
# Run the cell below to complete authentication.

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ### Import ADK components
#
# Now, import the specific components you'll need from the Agent Development Kit and the Generative AI library. This keeps your code organized and ensures we have access to the necessary building blocks.

# %%
from google.adk.agents import Agent, LlmAgent, SequentialAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types



from google.adk.tools.mcp_tool.mcp_toolset import McpToolset
from google.adk.tools.tool_context import ToolContext
from google.adk.tools.mcp_tool.mcp_session_manager import StdioConnectionParams
from mcp import StdioServerParameters

from google.adk.apps.app import App, ResumabilityConfig
from google.adk.tools.function_tool import FunctionTool
from google.adk.sessions import InMemorySessionService

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ### Helper functions
#
# We'll define some helper functions. If you are running this outside the Kaggle environment, you don't need to do this.

# %%
# Define helper functions that will be reused throughout the notebook

from IPython.core.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# ### Configure Retry Options
#
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# ---
#
# ## AI Agent with ADK
#
# ### What is an AI Agent?
#
# You've probably used an LLM like Gemini before, where you give it a prompt and it gives you a text response.
#
# `Prompt -> LLM -> Text`
#
# An AI Agent takes this one step further. An agent can think, take actions, and observe the results of those actions to give you a better answer.
#
# `Prompt -> Agent -> Thought -> Action -> Observation -> Final Answer`
#
# In this notebook, we'll build an agent that can take the action of searching Google. Let's see the difference!

# %% [markdown]
# ### Define your agent
#
# Now, let's build our agent. We'll configure an `Agent` by setting its key properties, which tell it what to do and how to operate.
#
# To learn more, check out the documentation related to [agents in ADK](https://google.github.io/adk-docs/agents/).
#
# These are the main properties we'll set:
#
# - **name** and **description**: A simple name and description to identify our agent.
# - **model**: The specific LLM that will power the agent's reasoning. We'll use "gemini-2.5-flash-lite".
# - **instruction**: The agent's guiding prompt. This tells the agent what its goal is and how to behave.
# - **tools**: A list of [tools](https://google.github.io/adk-docs/tools/) that the agent can use. To start, we'll give it the `google_search` tool, which lets it find up-to-date information online.

# %% [markdown]
# **Agent that helps retrieve the sugar free recipes**

# %%
recipe_agent = Agent(
    name="recipe_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the recipes of all sugarfree deserts using dried dates, figs and raisins.",
    instruction="You are a helpful assistant. Use Google Search to get the recipe for the sugarfree dessert.",
    tools=[google_search],
    output_key="recipe_generated",  # The result will be stored with this key.
)

print("✅ Recipe Agent defined.")
# Out:
# ✅ Recipe Agent defined.

# %% [markdown]
# **Ingredients Agent created to get all the ingredients only for the summary?**

# %%
ingredients_agent = Agent(
    name="ingredients_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the recipes of all sugarfree deserts using dried dates, figs and raisins.",
    instruction="Please only give me the ingredients for the recipe for the sugarfree dessert. {recipe_generated}",
    output_key="ingredients_generated",  # The result will be stored with this key.
)

print("✅ Ingredients Agent defined.")
# Out:
# ✅ Ingredients Agent defined.

# %% [markdown]
# **Agent to retrieve the couple stores the ingredients are available at?******

# %%
store_suggestion_agent = Agent(
    name="ingredients_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that get you the stores to buy the ingredients from?",
    instruction="Please give me the top 2 stores where the ingredients can be bought?. {ingredients_generated}",
    output_key="stores_suggestion_generated",  # The result will be stored with this key.
)

print("✅ Stores Suggestion Agent defined.")
# Out:
# ✅ Stores Suggestion Agent defined.

# %% [markdown]
# **Sequential Agent created to get the recipe, the ingredients and stores suggestion agents in a sequential manner.
#
# System with three specialized agents:
#
# recipe_agent - gets the recipe
# ingredients_agent - gets the ingredients
# stores suggestion agent - gets the stores the ingredients are available at

# %%
root_agent = SequentialAgent(
    name="RecipeWithImagePipeline",
    sub_agents=[recipe_agent, ingredients_agent, store_suggestion_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %% [markdown]
# ### Run your agent
#
# Now it's time to bring your agent to life and send it a query. To do this, you need a [`Runner`](https://google.github.io/adk-docs/runtime/), which is the central component within ADK that acts as the orchestrator. It manages the conversation, sends our messages to the agent, and handles its responses.
#
# **a. Create an `InMemoryRunner` and tell it to use our `root_agent`:**
# **Using run_debug to send out prompt and get the answer**

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Get me a sugar free recipe for pumpkin pie with ingredients and stores where the ingredients are available"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Get me a sugar free recipe for pumpkin pie with ingredients and stores where the ingredients are available
# recipe_assistant > Here's a sugar-free pumpkin pie recipe that uses dates for sweetness, along with information on where to find the ingredients.
#
# **Sugar-Free Pumpkin Pie (Naturally Sweetened with Dates)**
#
# This recipe creates a rich and flavorful pumpkin pie without refined sugars, relying on the natural sweetness of dates.
#
# **Ingredients:**
#
# *   **For the Filling:**
#     *   1 ½ cups pumpkin puree (ensure it's 100% pure pumpkin, not pie mix)
#     *   ½ cup soft Medjool dates, pitted and chopped
#     *   ¼ cup pure maple syrup
#     *   3 large eggs
#     *   1 cup milk (whole milk, almond milk, or coconut milk)
#     *   1 teaspoon cinnamon
#     *   1 teaspoon ground ginger
#     *   ⅛ teaspoon ground nutmeg (or ¼ tsp pumpkin pie spice)
#     *   ½ teaspoon salt
#     *   1 teaspoon vanilla extract (optional, but recommended)
# *   **For the Crust:**
#     *   1 pre-made 9-inch pie crust (check for sugar-free options if desired, or make your own whole-grain crust)
#
# **Instructions:**
#
# 1.  **Prepare the Dates:** If your dates are not soft, soak them in warm water for about 10-15 minutes until pliable. Drain them well.
# 2.  **Make the Date Paste:** In a food processor, combine the pitted and chopped dates with the ¼ cup of maple syrup. Process until a smooth paste forms.
# 3.  **Add Pumpkin and Eggs:** Add ½ cup of the pumpkin puree to the date mixture in the food processor and process until combined. Then, add the remaining 1 cup of pumpkin puree, eggs, milk, cinnamon, ginger, nutmeg, salt, and vanilla extract (if using). Process until the filling is smooth.
# 4.  **Prepare the Pie:** Preheat your oven to 350°F (175°C). Pour the pumpkin pie filling into the unbaked pie crust.
# 5.  **Bake:** Bake for 40-45 minutes, or until a knife inserted near the center comes out clean and the filling is set but not overly jiggly. Some recipes suggest an initial bake at 425°F for 15 minutes, then reducing to 350°F for 40-50 minutes.
# 6.  **Cool:** Let the pie cool on a wire rack for at least 2 hours. For best results, chill it in the refrigerator overnight before serving.
#
# **Where to Find Ingredients:**
#
# *   **Pumpkin Puree:** Canned 100% pure pumpkin puree is widely available at most major grocery stores, including Walmart, Target, and Kroger. You can also find it at specialty health food stores.
# *   **Dates (Medjool):** These can be found in the produce section or dried fruit aisle of most large supermarkets, health food stores, and online retailers like Amazon. Target and Walmart also carry them.
# *   **Maple Syrup:** Pure maple syrup is a common item in the baking aisle or syrup section of most grocery stores.
# *   **Spices (Cinnamon, Ginger, Nutmeg):** These are standard pantry staples available in the spice aisle of any grocery store.
# *   **Eggs and Milk:** Readily available at all grocery stores.
# *   **Pie Crust:** You can purchase pre-made pie crusts at the grocery store in the dairy or refrigerated baked goods section. Some brands offer sugar-free or gluten-free options. Alternatively, you can make your own crust.
#
# **Sweetener Alternatives:**
#
# If you prefer not to use dates as the sole sweetener, some recipes suggest using a blend of monk fruit and erythritol or allulose as a sugar substitute. These are often found in the baking or health food sections of larger grocery stores, or available online.
# ingredients_assistant > Here are the ingredients for the sugar-free pumpkin pie:
#
# **For the Filling:**
#
# *   1 ½ cups pumpkin puree (ensure it's 100% pure pumpkin, not pie mix)
# *   ½ cup soft Medjool dates, pitted and chopped
# *   ¼ cup pure maple syrup
# *   3 large eggs
# *   1 cup milk (whole milk, almond milk, or coconut milk)
# *   1 teaspoon cinnamon
# *   1 teaspoon ground ginger
# *   ⅛ teaspoon ground nutmeg (or ¼ tsp pumpkin pie spice)
# *   ½ teaspoon salt
# *   1 teaspoon vanilla extract (optional, but recommended)
#
# **For the Crust:**
#
# *   1 pre-made 9-inch pie crust (check for sugar-free options if desired, or make your own whole-grain crust)
#
# **Where to Find Ingredients:**
#
# *   **Pumpkin Puree:** Canned 100% pure pumpkin puree is widely available at most major grocery stores, including Walmart, Target, and Kroger. You can also find it at specialty health food stores.
# *   **Dates (Medjool):** These can be found in the produce section or dried fruit aisle of most large supermarkets, health food stores, and online retailers like Amazon. Target and Walmart also carry them.
# *   **Maple Syrup:** Pure maple syrup is a common item in the baking aisle or syrup section of most grocery stores.
# *   **Spices (Cinnamon, Ginger, Nutmeg):** These are standard pantry staples available in the spice aisle of any grocery store.
# *   **Eggs and Milk:** Readily available at all grocery stores.
# *   **Pie Crust:** You can purchase pre-made pie crusts at the grocery store in the dairy or refrigerated baked goods section. Some brands offer sugar-free or gluten-free options. Alternatively, you can make your own crust.
# ingredients_assistant > The top 2 stores where you can buy all the ingredients for the sugar-free pumpkin pie are:
#
# 1.  **Walmart:** You can find pumpkin puree, Medjool dates, maple syrup, all the spices, eggs, milk, and pre-made pie crusts here.
# 2.  **Target:** Similar to Walmart, Target carries all the necessary ingredients for the pumpkin pie, from pantry staples to fresh items.

# %% [markdown]
# 👉 Note that we are using the Python Runner directly in this notebook. You can also run agents using ADK command-line tools such as `adk run`, `adk web`, or `adk api_server`. To learn more, check out the documentation related to [runtime in ADK](https://google.github.io/adk-docs/runtime/).

# %% [markdown]
# **b. Now you can call the `.run_debug()` method to send our prompt and get an answer.**
#
# 👉 This method abstracts the process of session creation and maintenance and is used in prototyping. We'll explore "what sessions are and how to create them" on Day 3.

# %%
response = await runner.run_debug(
    "Give me a recipe for Apple Pie?  List the ingredients out separately and stores showing availability?"
)
# Out:
#  ### Continue session: debug_session_id
#
# User > Give me a recipe for Apple Pie?  List the ingredients out separately and stores showing availability?
# recipe_assistant > Here is a recipe for sugar-free apple pie, along with where you can find the necessary ingredients.
#
# **Sugar-Free Apple Pie**
#
# This recipe utilizes sugar substitutes to achieve a classic apple pie flavor without added sugars.
#
# **Ingredients:**
#
# *   **For the Filling:**
#     *   8 cups thinly sliced, peeled tart apples (about 10 medium apples, such as Granny Smith or a mix of tart and sweet)
#     *   Sugar substitute equivalent to 1 cup of sugar (e.g., Splenda, stevia, or monk fruit sweetener)
#     *   1/4 cup cornstarch (for thickening)
#     *   1 teaspoon ground cinnamon
#     *   1/8 teaspoon ground nutmeg
#     *   1 tablespoon lemon juice (to prevent browning and add brightness)
#     *   1 teaspoon vanilla extract (optional, for added flavor)
#     *   4 tablespoons butter, cut into small pieces
# *   **For the Crust:**
#     *   Dough for a double-crust pie (you can use pre-made sugar-free pie crusts or make your own)
#
# **Instructions:**
#
# 1.  **Prepare the Filling:** Preheat your oven to 375°F (190°C). In a large bowl, toss the sliced apples with lemon juice to prevent browning.
# 2.  In a separate medium bowl, whisk together the sugar substitute, cornstarch, cinnamon, and nutmeg.
# 3.  Add the dry spice mixture to the apples and toss to coat evenly. Stir in the vanilla extract, if using.
# 4.  **Assemble the Pie:** Roll out half of your pie dough and carefully line a 9-inch pie plate. Trim the edges, leaving enough overhang to flute.
# 5.  Pour the apple filling into the pie crust. Dot the top of the filling with the pieces of butter.
# 6.  Roll out the remaining pie dough for the top crust. You can create a full top crust with vents, a lattice top, or cut out shapes. Place the top crust over the filling and crimp the edges to seal.
# 7.  **Bake:** Bake for 35 minutes. Then, increase the oven temperature to 400°F (200°C) and bake for an additional 15-20 minutes, or until the crust is golden brown and the apples are tender and bubbly. (Some recipes suggest starting at 425°F for 15 minutes then reducing to 350°F for 40-50 minutes.)
# 8.  **Cool:** Let the pie cool on a wire rack for at least 2-3 hours before slicing and serving to allow the filling to set properly.
#
# **Where to Find Ingredients:**
#
# *   **Apples:** Fresh apples can be found in the produce section of all major grocery stores, including Walmart, Target, Kroger, and local supermarkets.
# *   **Sugar Substitutes:** Various sugar substitutes like Splenda, stevia, or monk fruit sweeteners are available in the baking aisle or the health food section of most large grocery stores (Walmart, Target, Kroger). Online retailers like Amazon also carry a wide selection.
# *   **Cornstarch:** This is a common pantry staple found in the baking aisle of all grocery stores.
# *   **Spices (Cinnamon, Nutmeg):** These are standard spices available in the spice aisle of any grocery store.
# *   **Lemon Juice, Vanilla Extract:** Available in the baking or produce section of grocery stores.
# *   **Butter, Eggs, Milk:** Readily available at all grocery stores.
# *   **Pie Crusts:** Pre-made pie crusts, including sugar-free options, can be found in the refrigerated baked goods section of most grocery stores (Walmart, Target, Kroger). You can also purchase ingredients to make your own crust.
#
# **Top Stores for All Ingredients:**
#
# 1.  **Walmart:** You can find all the necessary ingredients, from fresh produce like apples to pantry staples like sugar substitutes, spices, and pre-made pie crusts.
# 2.  **Target:** Similar to Walmart, Target offers a comprehensive selection of ingredients for this sugar-free apple pie recipe.
# 3.  **Kroger:** Kroger is another excellent option, carrying all the fresh produce, baking essentials, and pre-made crusts needed.
# ingredients_assistant > Here are the ingredients for the Apple Pie:
#
# **For the Filling:**
#
# *   8 cups thinly sliced, peeled tart apples (about 10 medium apples, such as Granny Smith or a mix of tart and sweet)
# *   Sugar substitute equivalent to 1 cup of sugar (e.g., Splenda, stevia, or monk fruit sweetener)
# *   1/4 cup cornstarch (for thickening)
# *   1 teaspoon ground cinnamon
# *   1/8 teaspoon ground nutmeg
# *   1 tablespoon lemon juice (to prevent browning and add brightness)
# *   1 teaspoon vanilla extract (optional, for added flavor)
# *   4 tablespoons butter, cut into small pieces
#
# **For the Crust:**
#
# *   Dough for a double-crust pie (you can use pre-made sugar-free pie crusts or make your own)
#
# **Stores Showing Availability:**
#
# *   **Apples:** The produce section of all major grocery stores like **Walmart**, **Target**, and **Kroger**.
# *   **Sugar Substitutes:** The baking aisle or health food section of large grocery stores like **Walmart**, **Target**, and **Kroger**. Also available online from retailers like Amazon.
# *   **Cornstarch:** The baking aisle of all grocery stores.
# *   **Spices (Cinnamon, Nutmeg):** The spice aisle of any grocery store.
# *   **Lemon Juice, Vanilla Extract:** The baking or produce section of grocery stores.
# *   **Butter:** The dairy section of all grocery stores.
# *   **Pie Crusts:** The refrigerated baked goods section of most grocery stores (**Walmart**, **Target**, **Kroger**).
# ingredients_assistant > As per your instructions, I will continue to process previous requests. If no further outputs are needed, I will exit or provide a summary. Please let me know if you have any more requests or if a summary is desired.

# %% [markdown]
# You can see a summary of ADK and its available languages in the response.
#
# ### How does it work?
#
# The agent performed a Google Search to get the latest information about ADK, and it knew to use this tool because:
#
# 1. The agent inspects and is aware of which tools it has available to use.
# 2. The agent's instructions specify the use of the search tool to get current information or if it is unsure of an answer.
#
# The best way to see the full, detailed trace of the agent's thoughts and actions is in the **ADK web UI**, which we'll set up later in this notebook.
#
# And we'll cover more detailed workflows for logging and observability later in the course.

# %% [markdown]
# ### 🚀 Checking out other sugar free recipes

# %%
response = await runner.run_debug("What's the recipe for Indian sweet Gulab Jamun?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the recipe for Indian sweet Gulab Jamun?
# recipe_assistant > I cannot provide a recipe for traditional Gulab Jamun as it inherently contains sugar. However, I can offer a sugar-free version of Gulab Jamun, which is a popular Indian dessert. These recipes often use sugar substitutes or natural sweeteners like dates to achieve a similar taste and texture without refined sugar.
#
# Here are a couple of options for sugar-free Gulab Jamun:
#
# **Option 1: Using a Sugar Substitute (e.g., Stevia, Erythritol, Monk Fruit)**
#
# This method focuses on replacing the sugar syrup with a sweetener of your choice.
#
# **Ingredients:**
#
# *   1 cup gulab jamun mix (or a homemade mix of milk powder, flour, and baking soda)
# *   1/4 cup water or milk (as needed for kneading)
# *   1 tablespoon ghee (clarified butter)
# *   1 cup water (for syrup)
# *   2-3 tablespoons natural sweetener (like stevia, erythritol, or monk fruit)
# *   1/2 teaspoon cardamom powder
# *   A few saffron strands (optional)
# *   Oil for frying
#
# **Instructions:**
#
# 1.  **Prepare the Dough:** In a bowl, mix the gulab jamun mix with ghee and water/milk to form a soft dough. Be careful not to over-knead.
# 2.  **Form Balls:** Roll the dough into small, smooth balls. Ensure there are no cracks, as this can cause them to break during frying.
# 3.  **Fry:** Heat oil or ghee on a low flame. Fry the gulab jamun balls until they are golden brown, turning occasionally for even cooking. Avoid high heat, which can brown the outside too quickly while leaving the inside uncooked.
# 4.  **Make Syrup:** In another pan, boil 1 cup of water with your chosen sweetener, cardamom powder, and saffron (if using). Simmer until slightly sticky.
# 5.  **Soak:** Add the fried gulab jamuns to the warm syrup. Let them soak for at least 30 minutes to an hour to absorb the sweetness and soften.
# 6.  **Serve:** Garnish with chopped pistachios or other nuts if desired, and serve warm or chilled.
#
# **Option 2: Naturally Sweetened with Dates**
#
# This recipe uses dates to sweeten the gulab jamun, offering a more natural approach.
#
# **Ingredients:**
#
# *   **For the Jamuns:**
#     *   1 cup almond flour (or whole wheat flour/oat flour)
#     *   1/4 cup oat flour (or whole wheat flour if not gluten-free)
#     *   1/3 cup Greek yogurt (or blended cottage cheese)
#     *   1/4 teaspoon baking soda
#     *   1/4 teaspoon cardamom powder
#     *   1 tablespoon coconut oil or ghee, melted
#     *   Pinch of salt
#     *   (Optional: Some recipes use koa, milk powder, and baking powder with dates)
# *   **For the Syrup:**
#     *   1/2 cup maple syrup (or date syrup)
#     *   1 cup water
#     *   4-5 crushed cardamom pods
#     *   Few saffron strands
#     *   1/2 teaspoon rose water
#
# **Instructions:**
#
# 1.  **Make the Dough:** In a bowl, mix the almond flour, oat flour, baking soda, cardamom powder, and salt. Add the Greek yogurt and melted ghee or coconut oil. Gently knead into a soft dough.
# 2.  **Form Balls:** Divide the dough into equal portions and roll each into a smooth ball. Some recipes suggest stuffing these balls with pitted dates.
# 3.  **Cook the Jamuns:** These can be air-fried at 360°F (180°C) for about 5 minutes per side, baked at 350°F (175°C) for 12-15 minutes, or traditionally deep-fried until golden.
# 4.  **Make the Syrup:** In a small saucepan, combine maple syrup (or date syrup), water, crushed cardamom pods, saffron, and rose water. Simmer for 5-8 minutes.
# 5.  **Soak and Serve:** Add the cooked jamuns to the warm syrup and let them soak.
#
# **Where to Find Ingredients:**
#
# *   **Gulab Jamun Mix/Milk Powder:** These are available at Indian grocery stores, specialty food stores, and the international aisle of larger supermarkets like Walmart, Target, and Kroger. They are also available online.
# *   **Ghee/Coconut Oil:** Found in the international aisle, baking section, or dairy section of most grocery stores.
# *   **Sugar Substitutes (Stevia, Erythritol, Monk Fruit):** Available in the baking aisle or health food section of major grocery stores (Walmart, Target, Kroger) and online.
# *   **Dates:** Found in the produce section or dried fruit aisle of most supermarkets, health food stores, and online.
# *   **Almond Flour/Oat Flour/Whole Wheat Flour:** Available in the baking or health food section of grocery stores.
# *   **Spices (Cardamom, Saffron):** Available in the spice aisle of any grocery store.
# *   **Rose Water:** Found in the international aisle or baking section of larger grocery stores.
# *   **Greek Yogurt/Milk:** Readily available at all grocery stores.
#
# **Note:** When making sugar-free versions, the texture and sweetness might vary slightly from traditional Gulab Jamun. It's recommended to follow specific recipes closely and adjust sweeteners to your preference.
# ingredients_assistant > I cannot provide a recipe for traditional Gulab Jamun as it inherently contains sugar. However, I can offer a sugar-free version of Gulab Jamun, which is a popular Indian dessert. These recipes often use sugar substitutes or natural sweeteners like dates to achieve a similar taste and texture without refined sugar.
#
# Here are a couple of options for sugar-free Gulab Jamun:
#
# **Option 1: Using a Sugar Substitute (e.g., Stevia, Erythritol, Monk Fruit)**
#
# This method focuses on replacing the sugar syrup with a sweetener of your choice.
#
# **Ingredients:**
#
# *   1 cup gulab jamun mix (or a homemade mix of milk powder, flour, and baking soda)
# *   1/4 cup water or milk (as needed for kneading)
# *   1 tablespoon ghee (clarified butter)
# *   1 cup water (for syrup)
# *   2-3 tablespoons natural sweetener (like stevia, erythritol, or monk fruit)
# *   1/2 teaspoon cardamom powder
# *   A few saffron strands (optional)
# *   Oil for frying
#
# **Option 2: Naturally Sweetened with Dates**
#
# This recipe uses dates to sweeten the gulab jamun, offering a more natural approach.
#
# **Ingredients:**
#
# *   **For the Jamuns:**
#     *   1 cup almond flour (or whole wheat flour/oat flour)
#     *   1/4 cup oat flour (or whole wheat flour if not gluten-free)
#     *   1/3 cup Greek yogurt (or blended cottage cheese)
#     *   1/4 teaspoon baking soda
#     *   1/4 teaspoon cardamom powder
#     *   1 tablespoon coconut oil or ghee, melted
#     *   Pinch of salt
#     *   (Optional: Some recipes use koa, milk powder, and baking powder with dates)
# *   **For the Syrup:**
#     *   1/2 cup maple syrup (or date syrup)
#     *   1 cup water
#     *   4-5 crushed cardamom pods
#     *   Few saffron strands
#     *   1/2 teaspoon rose water
# ingredients_assistant > I have processed your previous requests and provided the information you asked for regarding sugar-free Gulab Jamun recipes.
#
# Since there are no further explicit requests in your last prompt, I will now exit.

# %%
response = await runner.run_debug("What's the recipe for Indian sweet Gulab Jamun not using milk powder?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the recipe for Indian sweet Gulab Jamun not using milk powder?
# recipe_assistant > Yes, it's definitely possible to make delicious Gulab Jamun without milk powder! Traditional Gulab Jamun often uses "khoya" or "mawa" (reduced milk solids), not milk powder, as the base. However, there are several modern adaptations that achieve a similar texture using alternative ingredients.
#
# Here's a recipe for sugar-free Gulab Jamun that does not use milk powder, focusing on natural sweeteners and common pantry staples:
#
# **Sugar-Free Gulab Jamun (No Milk Powder, Naturally Sweetened with Dates & Maple Syrup)**
#
# This recipe utilizes almond flour and other gluten-free flours for the "jamuns," and a sugar-free syrup for soaking.
#
# **Ingredients:**
#
# *   **For the Jamuns:**
#     *   ¾ cup almond flour
#     *   ¼ cup oat flour (or whole wheat flour if not gluten-free)
#     *   ⅓ cup Greek yogurt (or blended cottage cheese)
#     *   ¼ teaspoon baking soda
#     *   ¼ teaspoon cardamom powder
#     *   1 tablespoon coconut oil or ghee, melted
#     *   Pinch of salt
#     *   *(Optional: some recipes use bread and cashews or a mix of flours and sweet potato puree)*
# *   **For the Sugar-Free Syrup:**
#     *   ½ cup maple syrup (or date syrup)
#     *   1 cup water
#     *   4-5 crushed cardamom pods
#     *   Few saffron strands (optional)
#     *   ½ teaspoon rose water (optional)
# *   **For Frying/Cooking:**
#     *   Oil for frying, or you can air fry or bake the jamuns
#
# **Instructions:**
#
# 1.  **Make the Dough:** In a bowl, mix together the almond flour, oat flour, baking soda, cardamom powder, and a pinch of salt. Add the Greek yogurt and melted coconut oil or ghee. Gently knead into a soft dough. If it feels dry, add a tablespoon of milk or water at a time until it forms a pliable dough. Be careful not to over-knead.
# 2.  **Form the Jamuns:** Divide the dough into 6 equal portions and roll each into a smooth, small ball with your palms. Ensure there are no cracks, as this can cause them to break during cooking.
# 3.  **Cook the Jamuns:**
#     *   **Air Fryer:** Air fry at 360°F (180°C) for about 5 minutes, flip, and air fry for another 5 minutes until golden and slightly crisp.
#     *   **Oven:** Bake at 350°F (175°C) for 12-15 minutes.
#     *   **Frying:** Heat oil in a pan over medium-low heat. Fry the jamun balls in batches until golden brown, turning them occasionally for even cooking.
# 4.  **Make the Syrup:** In a small saucepan, combine the maple syrup (or date syrup), water, crushed cardamom pods, and saffron (if using). Let it simmer for 5-8 minutes. Stir in the rose water (if using) and set aside.
# 5.  **Soak the Jamuns:** Add the warm, cooked jamuns to the warm syrup. Let them soak for at least 30 minutes to an hour to absorb the sweetness and soften.
# 6.  **Serve:** Garnish with chopped pistachios or other nuts if desired, and serve warm or chilled.
#
# **Where to Find Ingredients:**
#
# *   **Almond Flour, Oat Flour, Coconut Oil, Cardamom Powder, Rose Water, Saffron:** These are available in the baking aisle or health food section of major grocery stores like Walmart, Target, and Kroger. They are also readily available online.
# *   **Greek Yogurt/Blended Cottage Cheese, Milk/Water:** Readily available at all grocery stores.
# *   **Maple Syrup/Date Syrup:** Found in the baking aisle or syrup section of most grocery stores.
# *   **Pistachios (for garnish):** Available in the baking aisle or snack section of grocery stores.
# *   **Oil for Frying:** Standard cooking oil available at all grocery stores.
#
# **Stores Where You Can Buy All Ingredients:**
#
# 1.  **Walmart:** You can find all the necessary ingredients, from flours and dairy to sweeteners and spices.
# 2.  **Target:** Target also offers a wide selection of these ingredients.
# 3.  **Kroger:** Kroger and other large supermarket chains will carry most, if not all, of these items.
#
# Enjoy your homemade, sugar-free Gulab Jamun!
# ingredients_assistant > Here are the ingredients for the Indian sweet Gulab Jamun, made without milk powder:
#
# *   **For the Jamuns:**
#     *   ¾ cup almond flour
#     *   ¼ cup oat flour (or whole wheat flour if not gluten-free)
#     *   ⅓ cup Greek yogurt (or blended cottage cheese)
#     *   ¼ teaspoon baking soda
#     *   ¼ teaspoon cardamom powder
#     *   1 tablespoon coconut oil or ghee, melted
#     *   Pinch of salt
#     *   *(Optional: some recipes use bread and cashews or a mix of flours and sweet potato puree)*
# *   **For the Sugar-Free Syrup:**
#     *   ½ cup maple syrup (or date syrup)
#     *   1 cup water
#     *   4-5 crushed cardamom pods
#     *   Few saffron strands (optional)
#     *   ½ teaspoon rose water (optional)
# *   **For Frying/Cooking:**
#     *   Oil for frying, or you can air fry or bake the jamuns
# ingredients_assistant > I have processed your previous requests and provided the information you asked for.
#
# Since there are no further explicit requests in your last prompt, I will now exit.

# %% [markdown]
# ---
#
# ## 💻 Section 3: Try the ADK Web Interface
#
# ### Overview
#
# ADK includes a built-in web interface for interactively chatting with, testing, and debugging your agents.
#
# <img width="1200" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/adk-web-ui.gif" alt="ADK Web UI" />
#
# To use the ADK web UI, you'll need to create an agent with Python files using the `adk create` command.
#
# Run the command below to generate a `sample-agent` folder that contains all the necessary files, including `agent.py` for your code, an `.env` file with your API key pre-configured, and an `__init__.py` file:

# %%
# !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in /kaggle/working/sample-agent:
# - .env
# - __init__.py
# - agent.py

# %% [markdown]
# Get your custom URL to access the ADK web UI in the Kaggle Notebooks environment:

# %%
url_prefix = get_adk_proxy_url()
# Out:
#     <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
#         <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
#             <strong>⚠️ IMPORTANT: Action Required</strong>
#         </div>
#         <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
#             The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
#             <ol style="margin-top: 10px; padding-left: 20px;">
#                 <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
#                 <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
#                 <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
#             </ol>
#             <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
#         </div>
#         <a href='https://kkb-production.jupyter-proxy.kaggle.net/k/281107394/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..vqZfhQ3tkPFDAR_ZWQjxNw.M331jf27xL2377FXIC4sGRmTl9xQNIV8H_qFo3fb6RfAsU_Q6ryPexD_3hdsaAM4VxNSP46MVrWGKSlAYycBfnprTj2m0gYyVMiHShFjXykChkvF11rCBjC5LlfR7hX46ts4-cKOl0u_gRPSZGgwQB-tHfWYwhr1E_7fz24PrrY0xd3TCuAYHgcY1DUQp8IO07WdZq2676AZ45Wo7s-651EB5C5dm4-Q7WVHv9020qkKjX-_pusFrqdb3urWZg6B.AnevW0C-anRnTDNsTEM0xw/proxy/proxy/8000' target='_blank' style="
#             display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
#             text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
#             Open ADK Web UI (after running cell below) ↗
#         </a>
#     </div>

# %% [markdown]
# Now we can run ADK web:

# %%
# !adk web --url_prefix {url_prefix}
# Out:
# /usr/local/lib/python3.11/dist-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /usr/local/lib/python3.11/dist-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [93]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     35.191.70.220:0 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     35.191.70.222:0 - "GET /dev-ui/ HTTP/1.1" 200 OK
# INFO:     35.191.70.220:0 - "GET /dev-ui/chunk-2WH2EVR6.js HTTP/1.1" 200 OK
# INFO:     35.191.70.222:0 - "GET /dev-ui/main-OS2OH2S3.js HTTP/1.1" 200 OK
# INFO:     35.191.70.221:0 - "GET /dev-ui/polyfills-B6TNHZQ6.js HTTP/1.1" 200 OK
# INFO:     35.191.70.223:0 - "GET /dev-ui/styles-EVMPSV3U.css HTTP/1.1" 200 OK
# INFO:     35.191.70.220:0 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 200 OK
# INFO:     35.191.70.221:0 - "GET /dev-ui/adk_favicon.svg HTTP/1.1" 200 OK
# INFO:     35.191.70.221:0 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     35.191.70.220:0 - "GET /dev-ui/assets/ADK-512-color.svg HTTP/1.1" 200 OK
# INFO:     35.191.70.223:0 - "GET /builder/app/sample-agent?ts=1763875535973 HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.cli.adk_web_server:New session created: 589dab27-8e26-452f-8436-036e695510ce
# INFO:     35.191.70.221:0 - "POST /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.70.221:0 - "GET /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.70.223:0 - "GET /apps/sample-agent/users/user/sessions/589dab27-8e26-452f-8436-036e695510ce HTTP/1.1" 200 OK
# INFO:     35.191.70.221:0 - "GET /debug/trace/session/589dab27-8e26-452f-8436-036e695510ce HTTP/1.1" 200 OK
# INFO:     35.191.70.220:0 - "GET /apps/sample-agent/eval_results HTTP/1.1" 200 OK
# INFO:     35.191.70.222:0 - "GET /apps/sample-agent/eval_sets HTTP/1.1" 200 OK
# INFO:     35.191.70.222:0 - "GET /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.70.220:0 - "GET /apps/sample-agent/users/user/sessions/589dab27-8e26-452f-8436-036e695510ce HTTP/1.1" 200 OK
# INFO:     35.191.70.221:0 - "GET /debug/trace/session/589dab27-8e26-452f-8436-036e695510ce HTTP/1.1" 200 OK

# %% [markdown]
# Now you can access the ADK dev UI using the link above.
#
# Once you open the link, you'll see the ADK web interface where you can ask your ADK agent questions.
#
# Note: This sample agent does not have any tools enabled (like Google Search). It is a basic agent designed specifically to let you explore the UI features.
#
# ‼️ **IMPORTANT: DO NOT SHARE THE PROXY LINK** with anyone - treat it as sensitive data as it contains your authentication token in the URL.
