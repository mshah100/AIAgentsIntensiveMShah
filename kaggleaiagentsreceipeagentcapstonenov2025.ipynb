# %% [markdown]
# # Agents Intensive - Capstone Project - Monisha Shah
#
# **Kaggle 5-day Agents course!**
#
# Creating agents to get the recipes for sugar free deserts along with Ingredients.
#
# Using a Sequential Agents to retrieve the recipe for the desert and where to buy the ingredients from.

# %% [markdown]
# ### Install dependencies google agent development kit library
#
# The Kaggle Notebooks environment includes a pre-installed version of the [google-adk](https://google.github.io/adk-docs/) library for Python and its required dependencies, so you don't need to install additional packages in this notebook.
#
# To install and use ADK in your own Python development environment outside of this course, you can do so by running:
#
# ```
# pip install google-adk
# ```

# %% [markdown]
# ### Configure your Gemini API Key
#
# This notebook uses the [Gemini API](https://ai.google.dev/gemini-api/docs), which requires authentication.
#
# **1. Get your API key**
#
# If you don't have one already, create an [API key in Google AI Studio](https://aistudio.google.com/app/api-keys).
#
# **2. Add the key to Kaggle Secrets**
#
# Next, you will need to add your API key to your Kaggle Notebook as a Kaggle User Secret.
#
# 1. In the top menu bar of the notebook editor, select `Add-ons` then `Secrets`.
# 2. Create a new secret with the label `GOOGLE_API_KEY`.
# 3. Paste your API key into the "Value" field and click "Save".
# 4. Ensure that the checkbox next to `GOOGLE_API_KEY` is selected so that the secret is attached to the notebook.
#
# **3. Authenticate in the notebook**
#
# Run the cell below to complete authentication.

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ### Import ADK components
#
# Now, import the specific components you'll need from the Agent Development Kit and the Generative AI library. This keeps your code organized and ensures we have access to the necessary building blocks.

# %%
from google.adk.agents import Agent, LlmAgent, SequentialAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import Runner, InMemoryRunner
from google.adk.sessions import InMemorySessionService
from google.adk.memory import InMemoryMemoryService
from google.adk.tools import google_search
from google.genai import types

from google.adk.tools import load_memory, preload_memory



from google.adk.tools.mcp_tool.mcp_toolset import McpToolset
from google.adk.tools.tool_context import ToolContext
from google.adk.tools.mcp_tool.mcp_session_manager import StdioConnectionParams
from mcp import StdioServerParameters

from google.adk.apps.app import App, ResumabilityConfig
from google.adk.tools.function_tool import FunctionTool
from google.adk.sessions import InMemorySessionService

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ### Helper functions
#
# We'll define some helper functions. If you are running this outside the Kaggle environment, you don't need to do this.

# %%
# Define helper functions that will be reused throughout the notebook

from IPython.core.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# ### Configure Retry Options
#
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# ---
#
# ## AI Agent with ADK
#
# ### What is an AI Agent?
#
# You've probably used an LLM like Gemini before, where you give it a prompt and it gives you a text response.
#
# `Prompt -> LLM -> Text`
#
# An AI Agent takes this one step further. An agent can think, take actions, and observe the results of those actions to give you a better answer.
#
# `Prompt -> Agent -> Thought -> Action -> Observation -> Final Answer`
#
# In this notebook, we'll build an agent that can take the action of searching Google. Let's see the difference!

# %% [markdown]
# ### Define your agent
#
# Now, let's build our agent. We'll configure an `Agent` by setting its key properties, which tell it what to do and how to operate.
#
# To learn more, check out the documentation related to [agents in ADK](https://google.github.io/adk-docs/agents/).
#
# These are the main properties we'll set:
#
# - **name** and **description**: A simple name and description to identify our agent.
# - **model**: The specific LLM that will power the agent's reasoning. We'll use "gemini-2.5-flash-lite".
# - **instruction**: The agent's guiding prompt. This tells the agent what its goal is and how to behave.
# - **tools**: A list of [tools](https://google.github.io/adk-docs/tools/) that the agent can use. To start, we'll give it the `google_search` tool, which lets it find up-to-date information online.

# %% [markdown]
# **Agent that helps retrieve the sugar free recipes**

# %%
# Define recipe agent an LlmAgent

recipe_agent = LlmAgent(
    name="recipe_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the recipes of all sugarfree deserts using dried dates, figs and raisins.",
    instruction="You are a helpful assistant. Use Google Search to get the recipe for the sugarfree dessert.",
    tools=[google_search],
    output_key="recipe_generated",  # The result will be stored with this key.
)

print("✅ Recipe Agent defined.")
# Out:
# ✅ Recipe Agent defined.

# %% [markdown]
# **Ingredients Agent created to get all the ingredients only for the summary?**

# %%
ingredients_agent = LlmAgent(
    name="ingredients_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the recipes of all sugarfree deserts using dried dates, figs and raisins.",
    instruction="Please only give me the ingredients for the recipe for the sugarfree dessert. {recipe_generated}",
    output_key="ingredients_generated",  # The result will be stored with this key.
)

print("✅ Ingredients Agent defined.")
# Out:
# ✅ Ingredients Agent defined.

# %% [markdown]
# **Agent to retrieve the couple stores the ingredients are available at?******

# %%
store_suggestion_agent = LlmAgent(
    name="ingredients_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that get you the stores to buy the ingredients from?",
    instruction="Please give me the top 2 stores where the ingredients can be bought?. {ingredients_generated}",
    output_key="stores_suggestion_generated",  # The result will be stored with this key.
)

print("✅ Stores Suggestion Agent defined.")
# Out:
# ✅ Stores Suggestion Agent defined.

# %% [markdown]
# **Agent to get the cumulative pricing for the ingredients**

# %%
price_estimation_agent = Agent(
    name="price_estimation_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the prices of theingredients",
    instruction="Please give me the prices of all the ingredients can be bought from one store?. {ingredients_generated}",
    output_key="prices_suggestion_generated",  # The result will be stored with this key.
)

print("✅ Prices Suggestion Agent defined.")
# Out:
# ✅ Prices Suggestion Agent defined.

# %% [markdown]
# **Sequential Agent created to get the recipe, the ingredients and stores suggestion agents in a sequential manner.
#
# System with three specialized agents:
#
# recipe_agent - gets the recipe
# ingredients_agent - gets the ingredients
# stores suggestion agent - gets the stores the ingredients are available at

# %%
root_agent = SequentialAgent(
    name="RecipeWithImagePipeline",
    sub_agents=[recipe_agent, ingredients_agent, store_suggestion_agent, price_estimation_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %% [markdown]
# ### Run your agent
#
# Now it's time to bring your agent to life and send it a query. To do this, you need a [`Runner`](https://google.github.io/adk-docs/runtime/), which is the central component within ADK that acts as the orchestrator. It manages the conversation, sends our messages to the agent, and handles its responses.
#
# **a. Create an `InMemoryRunner` and tell it to use our `root_agent`:**
# **Using run_debug to send out prompt and get the answer**

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Get me a sugar free recipe for pumpkin pie with ingredients and stores where the ingredients are available"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Get me a sugar free recipe for pumpkin pie with ingredients and stores where the ingredients are available
# recipe_assistant > Here's a sugar-free pumpkin pie recipe using dates and figs for sweetness.
#
# **Sugar-Free Pumpkin Pie with Dates and Figs**
#
# This recipe uses the natural sweetness of dates and figs, along with pumpkin and warm spices, to create a delicious and healthier dessert.
#
# **Ingredients:**
#
# *   1 pre-made 9-inch pie crust (check for sugar-free options if possible, or make your own whole-grain crust)
# *   1 cup pitted Medjool dates, packed
# *   1/4 cup pure maple syrup
# *   1 ½ cups pumpkin puree (ensure it's 100% pure pumpkin, not pumpkin pie filling)
# *   1 teaspoon cinnamon
# *   1 teaspoon ground ginger
# *   1/8 teaspoon ground nutmeg
# *   ½ teaspoon salt
# *   3 large eggs
# *   1 cup milk (whole milk, almond milk, or coconut milk)
# *   1 teaspoon vanilla extract (optional, for added flavor)
#
# **Instructions:**
#
# 1.  Preheat your oven to 350°F (175°C).
# 2.  In a food processor, combine the pitted dates and maple syrup. Pulse until the dates are broken down and the mixture is paste-like.
# 3.  Add ½ cup of the pumpkin puree to the food processor and process until smooth, scraping down the sides as needed.
# 4.  Add the remaining 1 cup of pumpkin puree, cinnamon, ginger, nutmeg, and salt. Process until the mixture is smooth.
# 5.  With the motor running, add the eggs one at a time, processing until each is well incorporated.
# 6.  Add the milk and vanilla extract (if using) and process until just combined.
# 7.  Pour the filling into your prepared pie crust.
# 8.  Bake for 40-45 minutes, or until the center is set but still slightly jiggly.
# 9.  Remove from the oven and let cool completely on a wire rack before slicing. For best results and a firmer texture, chilling the pie in the refrigerator overnight is recommended.
#
# **Availability of Ingredients:**
#
# *   **Pitted Dates (Medjool):** These can typically be found in the dried fruit or baking section of most major grocery stores (e.g., Walmart, Target, Kroger) and health food stores. They are also widely available online.
# *   **Maple Syrup:** Pure maple syrup is available in the syrup or baking aisle of most supermarkets and online.
# *   **Pumpkin Puree:** Look for canned 100% pure pumpkin puree in the canned goods aisle of grocery stores. Avoid "pumpkin pie filling" as it contains added sugar.
# *   **Spices (Cinnamon, Ginger, Nutmeg):** These are common pantry staples and can be found in the spice aisle of any grocery store.
# *   **Eggs:** Available in the dairy section of all supermarkets.
# *   **Milk:** Available in the dairy or non-dairy section of all supermarkets.
# *   **Vanilla Extract:** Found in the baking aisle of grocery stores.
# *   **Pie Crust:** Pre-made pie crusts can be found in the refrigerated or frozen section of most grocery stores. For a healthier option, you can make your own whole-grain crust using ingredients like whole wheat flour or almond flour.
#
# *Note: While this recipe is free of added refined sugars, natural sugars are present in the dates and maple syrup. If you are following a strict ketogenic or very low-sugar diet, you may want to explore recipes using alternative sweeteners like stevia or erythritol.*
# ingredients_assistant > Here are the ingredients for the sugar-free pumpkin pie recipe and where to find them:
#
# **Ingredients:**
#
# *   1 pre-made 9-inch pie crust (check for sugar-free options if possible, or make your own whole-grain crust)
# *   1 cup pitted Medjool dates, packed
# *   1/4 cup pure maple syrup
# *   1 ½ cups pumpkin puree (ensure it's 100% pure pumpkin, not pumpkin pie filling)
# *   1 teaspoon cinnamon
# *   1 teaspoon ground ginger
# *   1/8 teaspoon ground nutmeg
# *   ½ teaspoon salt
# *   3 large eggs
# *   1 cup milk (whole milk, almond milk, or coconut milk)
# *   1 teaspoon vanilla extract (optional, for added flavor)
#
# **Availability of Ingredients:**
#
# *   **Pitted Dates (Medjool):** Dried fruit or baking section of most major grocery stores (e.g., Walmart, Target, Kroger), health food stores, and online.
# *   **Maple Syrup:** Syrup or baking aisle of most supermarkets and online.
# *   **Pumpkin Puree:** Canned goods aisle of grocery stores. Look for 100% pure pumpkin puree.
# *   **Spices (Cinnamon, Ginger, Nutmeg):** Spice aisle of any grocery store.
# *   **Eggs:** Dairy section of all supermarkets.
# *   **Milk:** Dairy or non-dairy section of all supermarkets.
# *   **Vanilla Extract:** Baking aisle of grocery stores.
# *   **Pie Crust:** Refrigerated or frozen section of most grocery stores. You can also make your own.
# ingredients_assistant > The top 2 stores where the ingredients for the sugar-free pumpkin pie can be bought are:
#
# 1.  **Walmart:** This is a great option because it's a large supermarket that typically carries all the listed ingredients, from produce and dairy (eggs, milk) to baking supplies (pie crust, dates, maple syrup, pumpkin puree, spices, vanilla extract).
# 2.  **Target:** Similar to Walmart, Target's grocery section is comprehensive and usually stocks a wide variety of these ingredients, making it a convenient one-stop shop for most of your baking needs.
# price_estimation_assistant > I can help you get an idea of the prices for the ingredients if you choose to shop at **Walmart**. Please note that prices can vary significantly based on your specific location, brand choices, and any ongoing sales. These are estimated prices for common brands.
#
# Here's a price breakdown for the ingredients from Walmart:
#
# *   **1 pre-made 9-inch pie crust:** $2.50 - $4.00
# *   **1 cup pitted Medjool dates, packed** (often sold in 8-16 oz packages, so you'd use a portion): $5.00 - $8.00 for a package
# *   **1/4 cup pure maple syrup** (often sold in 8-12 oz bottles): $6.00 - $10.00 for a bottle
# *   **1 ½ cups pumpkin puree** (usually sold in 15 oz cans, so you'd need two): $2.00 - $3.00 per can (so $4.00 - $6.00 total)
# *   **1 teaspoon cinnamon, 1 teaspoon ground ginger, 1/8 teaspoon ground nutmeg** (these are typically small amounts from larger spice jars): $3.00 - $5.00 per spice jar (you'd likely only need to buy one or two new ones for this recipe)
# *   **½ teaspoon salt** (a common pantry staple, usually very inexpensive): $1.00 - $2.00 for a box
# *   **3 large eggs** (sold in dozens): $3.00 - $5.00 per dozen
# *   **1 cup milk** (whole milk, almond milk, or coconut milk - prices vary by type, usually sold in half-gallon or gallon containers): $3.00 - $6.00 per half-gallon
# *   **1 teaspoon vanilla extract** (optional, usually sold in small bottles): $4.00 - $7.00 per bottle
#
# **Estimated Total Cost for Ingredients at Walmart:**
#
# Adding up the lower ends of the estimates, you could potentially spend around **$30.00 - $35.00** for all the ingredients.
# Adding up the higher ends, the cost could be closer to **$40.00 - $50.00+**.
#
# **Important Considerations:**
#
# *   **Bulk Purchases:** Many of these ingredients (spices, salt, sugar, flour if making your own crust) are pantry staples that you likely already have or will use in other recipes. The cost for just the *amount needed* for this one recipe would be much less than buying a whole new container.
# *   **Brand Variation:** Generic or store brands will generally be cheaper than name brands.
# *   **Unit Price:** You're buying larger containers of things like dates, maple syrup, and milk, but only using a portion for this recipe. The "cost per recipe" would be lower than the total package price.
# *   **Making Your Own Crust:** If you make your own whole-grain crust, the cost would be for ingredients like whole wheat flour or almond flour, which might be more or less depending on what you have and what you use.

# %% [markdown]
# 👉 Note that we are using the Python Runner directly in this notebook. You can also run agents using ADK command-line tools such as `adk run`, `adk web`, or `adk api_server`. To learn more, check out the documentation related to [runtime in ADK](https://google.github.io/adk-docs/runtime/).

# %% [markdown]
# **b. Now you can call the `.run_debug()` method to send our prompt and get an answer.**
#
# 👉 This method abstracts the process of session creation and maintenance and is used in prototyping. We'll explore "what sessions are and how to create them" on Day 3.

# %%
response = await runner.run_debug(
    "Give me a recipe for Apple Pie?  List the ingredients out separately and stores showing availability?"
)
# Out:
#  ### Continue session: debug_session_id
#
# User > Give me a recipe for Apple Pie?  List the ingredients out separately and stores showing availability?
# recipe_assistant > Here's a classic apple pie recipe, with ingredients and where to find them:
#
# **Classic Apple Pie**
#
# This recipe yields a delicious, comforting apple pie with a flaky crust and a perfectly spiced apple filling.
#
# **Ingredients:**
#
# *   **For the Crust (makes enough for a double-crust pie):**
#     *   2 ½ cups all-purpose flour
#     *   1 teaspoon salt
#     *   1 cup (2 sticks) unsalted butter, cold and cut into cubes
#     *   ½ cup ice water (plus more if needed)
# *   **For the Filling:**
#     *   6-8 medium apples (a mix of varieties like Granny Smith, Honeycrisp, and Fuji is recommended), peeled, cored, and sliced about ¼-inch thick
#     *   ¾ cup granulated sugar (or adjust to your sweetness preference)
#     *   2 tablespoons all-purpose flour (or cornstarch for thickening)
#     *   1 teaspoon ground cinnamon
#     *   ¼ teaspoon ground nutmeg
#     *   ⅛ teaspoon ground allspice (optional)
#     *   1 tablespoon lemon juice (from about ½ lemon)
#     *   2 tablespoons unsalted butter, cut into small pieces
# *   **For the Egg Wash (optional, for a golden crust):**
#     *   1 large egg, beaten with 1 tablespoon water
#
# **Availability of Ingredients:**
#
# *   **All-purpose flour:** Available in the baking aisle of all major grocery stores (e.g., Walmart, Target, Kroger), as well as smaller grocery stores and online.
# *   **Salt:** A pantry staple, available in the spice aisle or baking section of all grocery stores.
# *   **Unsalted butter:** Available in the dairy section of all grocery stores.
# *   **Ice water:** Made from tap water, readily available at home.
# *   **Apples:** Available in the produce section of all grocery stores. A mix of tart and sweet varieties is best for flavor balance.
# *   **Granulated sugar:** Available in the baking aisle of all grocery stores.
# *   **Cornstarch (if using instead of flour for thickening):** Available in the baking aisle of all grocery stores.
# *   **Spices (Cinnamon, Nutmeg, Allspice):** Available in the spice aisle of all grocery stores.
# *   **Lemon juice:** Available in the produce section (fresh lemons) or in bottles in the beverage or baking aisle of grocery stores.
# *   **Eggs:** Available in the dairy section of all grocery stores.
#
# **Where to Buy Ingredients:**
#
# The top 2 stores where the ingredients for the apple pie can be bought are:
#
# 1.  **Walmart:** This is a great option because it's a large supermarket that typically carries all the listed ingredients. You can find produce (apples, lemons), dairy (butter, eggs, milk), and baking supplies (flour, sugar, spices, cornstarch, pie crust ingredients if not making from scratch) all in one place.
# 2.  **Target:** Similar to Walmart, Target's grocery section is comprehensive and usually stocks a wide variety of these ingredients, making it a convenient one-stop shop for most of your baking needs, from fresh produce to pantry staples.
#
# **Instructions:**
#
# 1.  **Make the Pie Crust:** In a large bowl, whisk together the flour and salt. Cut in the cold butter using a pastry blender or your fingertips until the mixture resembles coarse crumbs with some pea-sized pieces of butter remaining. Gradually add ice water, 1 tablespoon at a time, mixing until the dough just comes together. Divide the dough in half, flatten each half into a disk, wrap in plastic wrap, and refrigerate for at least 30 minutes.
# 2.  **Prepare the Filling:** In a large bowl, combine the sliced apples, sugar, flour (or cornstarch), cinnamon, nutmeg, allspice (if using), and lemon juice. Toss gently to coat the apples evenly.
# 3.  **Assemble the Pie:** On a lightly floured surface, roll out one disk of pie dough into a 12-inch circle. Carefully transfer it to a 9-inch pie plate. Trim the edges, leaving about a ½-inch overhang. Pour the apple filling into the crust and dot with the small pieces of butter.
# 4.  **Add the Top Crust:** Roll out the second disk of dough. You can place it whole over the filling, cut vents in it, or cut it into strips for a lattice top. Crimp the edges of the top and bottom crusts together to seal.
# 5.  **Bake the Pie:** Preheat your oven to 400°F (200°C). If using an egg wash, brush it over the top crust. Place the pie on a baking sheet (to catch any drips) and bake for 20 minutes.
# 6.  **Reduce Heat and Continue Baking:** Reduce the oven temperature to 375°F (190°C) and continue baking for another 30-40 minutes, or until the crust is golden brown and the filling is bubbling. If the crust starts to brown too quickly, you can loosely tent the pie with aluminum foil.
# 7.  **Cool and Serve:** Let the pie cool completely on a wire rack for at least 2-3 hours before slicing and serving. This allows the filling to set properly.
# ingredients_assistant > Here are the ingredients for a classic apple pie and where to find them:
#
# **For the Crust (makes enough for a double-crust pie):**
#
# *   2 ½ cups all-purpose flour
# *   1 teaspoon salt
# *   1 cup (2 sticks) unsalted butter, cold and cut into cubes
# *   ½ cup ice water (plus more if needed)
#
# **For the Filling:**
#
# *   6-8 medium apples (a mix of varieties like Granny Smith, Honeycrisp, and Fuji is recommended), peeled, cored, and sliced about ¼-inch thick
# *   ¾ cup granulated sugar (or adjust to your sweetness preference)
# *   2 tablespoons all-purpose flour (or cornstarch for thickening)
# *   1 teaspoon ground cinnamon
# *   ¼ teaspoon ground nutmeg
# *   ⅛ teaspoon ground allspice (optional)
# *   1 tablespoon lemon juice (from about ½ lemon)
# *   2 tablespoons unsalted butter, cut into small pieces
#
# **For the Egg Wash (optional, for a golden crust):**
#
# *   1 large egg, beaten with 1 tablespoon water
#
# **Availability of Ingredients:**
#
# *   **All-purpose flour:** Available in the baking aisle of all major grocery stores (e.g., Walmart, Target, Kroger), as well as smaller grocery stores and online.
# *   **Salt:** A pantry staple, available in the spice aisle or baking section of all grocery stores.
# *   **Unsalted butter:** Available in the dairy section of all grocery stores.
# *   **Ice water:** Made from tap water, readily available at home.
# *   **Apples:** Available in the produce section of all grocery stores. A mix of tart and sweet varieties is best for flavor balance.
# *   **Granulated sugar:** Available in the baking aisle of all grocery stores.
# *   **Cornstarch (if using instead of flour for thickening):** Available in the baking aisle of all grocery stores.
# *   **Spices (Cinnamon, Nutmeg, Allspice):** Available in the spice aisle of all grocery stores.
# *   **Lemon juice:** Available in the produce section (fresh lemons) or in bottles in the beverage or baking aisle of grocery stores.
# *   **Eggs:** Available in the dairy section of all grocery stores.
#
# **Where to Buy Ingredients:**
#
# The top 2 stores where the ingredients for the apple pie can be bought are:
#
# 1.  **Walmart:** This is a great option because it's a large supermarket that typically carries all the listed ingredients. You can find produce (apples, lemons), dairy (butter, eggs), and baking supplies (flour, sugar, spices, cornstarch).
# 2.  **Target:** Similar to Walmart, Target's grocery section is comprehensive and usually stocks a wide variety of these ingredients, making it a convenient one-stop shop for most of your baking needs.
# ingredients_assistant > I'm sorry, but I cannot "continue processing previous requests as instructed" because the previous interactions were about different recipes (sugar-free pumpkin pie and classic apple pie). I don't have a memory of a continuous "processing" of a single request.
#
# If you would like a new recipe, or if you have another request related to the previous recipes, please let me know! Otherwise, I will consider this interaction complete.
# price_estimation_assistant > Here is a classic apple pie recipe with a breakdown of the ingredients and where to find them:
#
# **Classic Apple Pie Recipe**
#
# **Yields:** 1 double-crust 9-inch pie
# **Prep time:** 45 minutes
# **Bake time:** 50-60 minutes
#
# **Ingredients:**
#
# **For the Pie Crust:**
# *   2 ½ cups all-purpose flour
# *   1 teaspoon salt
# *   1 cup (2 sticks) unsalted butter, cold and cut into cubes
# *   ½ cup ice water (plus more if needed)
#
# **For the Apple Filling:**
# *   6-8 medium apples (a mix of varieties like Granny Smith, Honeycrisp, and Fuji is recommended), peeled, cored, and sliced about ¼-inch thick
# *   ¾ cup granulated sugar (or adjust to your sweetness preference)
# *   2 tablespoons all-purpose flour (or cornstarch for thickening)
# *   1 teaspoon ground cinnamon
# *   ¼ teaspoon ground nutmeg
# *   ⅛ teaspoon ground allspice (optional)
# *   1 tablespoon lemon juice (from about ½ lemon)
# *   2 tablespoons unsalted butter, cut into small pieces
#
# **For the Egg Wash (optional):**
# *   1 large egg, beaten with 1 tablespoon water
#
# ---
#
# **Ingredient List and Store Availability:**
#
# Here are the ingredients you'll need for the apple pie, along with where you can typically find them:
#
# *   **All-purpose flour:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Salt:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Spice Aisle or Baking Aisle.
#
# *   **Unsalted butter:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Dairy Section.
#
# *   **Ice water:**
#     *   **Stores:** (No purchase necessary) Made from tap water at home.
#
# *   **Apples:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, farmers' markets, online produce delivery services.
#     *   **Aisle:** Produce Section.
#     *   **Note:** Look for a mix of tart (like Granny Smith) and sweet (like Honeycrisp or Fuji) for the best flavor balance.
#
# *   **Granulated sugar:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Cornstarch (optional, for thickening):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Spices (Cinnamon, Nutmeg, Allspice):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Spice Aisle.
#
# *   **Lemon juice:**
#     *   **Stores:**
#         *   **Fresh Lemons:** Walmart, Target, Kroger, Safeway, most local grocery stores. (Produce Section)
#         *   **Bottled Lemon Juice:** Walmart, Target, Kroger, Safeway, most local grocery stores. (Beverage Aisle or Baking Aisle)
#
# *   **Eggs:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Dairy Section.

# %% [markdown]
# You can see a summary of ADK and its available languages in the response.
#
# ### How does it work?
#
# The agent performed a Google Search to get the latest information about ADK, and it knew to use this tool because:
#
# 1. The agent inspects and is aware of which tools it has available to use.
# 2. The agent's instructions specify the use of the search tool to get current information or if it is unsure of an answer.
#
# The best way to see the full, detailed trace of the agent's thoughts and actions is in the **ADK web UI**, which we'll set up later in this notebook.
#
# And we'll cover more detailed workflows for logging and observability later in the course.

# %% [markdown]
# ### 🚀 Checking out other sugar free recipes

# %%
response = await runner.run_debug("What's the recipe for Indian sweet Gulab Jamun?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the recipe for Indian sweet Gulab Jamun?
# recipe_assistant > Here is a recipe for Gulab Jamun, a popular Indian sweet, along with ingredient information.
#
# **Gulab Jamun Recipe**
#
# Gulab Jamun are soft, spongy, deep-fried dumplings soaked in a fragrant sugar syrup, often flavored with cardamom and rosewater. They are a staple at Indian celebrations and festivals.
#
# **Ingredients:**
#
# *   **For the Gulab Jamun Dough:**
#     *   1 cup milk powder (full-fat is recommended)
#     *   ½ cup all-purpose flour (maida)
#     *   ½ teaspoon baking powder
#     *   ¼ teaspoon baking soda (optional, some recipes use it)
#     *   2-3 tablespoons ghee (clarified butter), softened, or unsalted butter
#     *   2-3 tablespoons milk (warm, as needed)
#     *   Pinch of cardamom powder (optional, for dough)
# *   **For the Sugar Syrup:**
#     *   2 cups granulated sugar
#     *   2 cups water
#     *   4-6 green cardamom pods, lightly crushed
#     *   A few drops of rose water (optional, for fragrance)
#     *   A pinch of saffron strands soaked in 2 tbsp warm water (optional, for color and flavor)
#     *   1 teaspoon lemon juice (optional, helps prevent crystallization)
# *   **For Frying:**
#     *   Ghee or neutral oil (like sunflower oil) for deep frying
# *   **For Garnish (optional):**
#     *   Chopped pistachios or almonds
#
# **Where to Buy Ingredients:**
#
# *   **Milk Powder, All-Purpose Flour, Sugar, Baking Powder/Soda, Cardamom, Rose Water, Saffron:** These can be found in the baking aisle or international foods section of most major grocery stores like Walmart and Target. Indian grocery stores are also excellent sources for these items, often carrying a wider variety of specific brands. Online retailers like Swiggy Instamart or Amazon also offer these ingredients.
# *   **Ghee/Butter:** Ghee is available in the international foods or dairy section of many supermarkets. Butter is found in the dairy section of all grocery stores.
# *   **Fresh Milk:** Available in the dairy section of all grocery stores.
# *   **Apples:** Available in the produce section of all grocery stores. A mix of tart and sweet varieties is best for flavor balance.
# *   **Lemons:** Available in the produce section of all grocery stores.
# *   **Vegetable Oil/Sunflower Oil:** Available in the cooking oil aisle of all grocery stores.
#
# **Instructions:**
#
# 1.  **Prepare the Sugar Syrup:** In a wide pot, combine sugar, water, and crushed cardamom pods. Heat over medium flame, stirring until the sugar dissolves. Let it simmer for about 5-7 minutes, or until it becomes slightly sticky (you should be able to form a sticky thread when you cool a drop between your fingers). Do not let it reach a string consistency, as this can make the gulab jamun hard. Stir in rose water, saffron (if using), and lemon juice. Keep the syrup warm over very low heat.
# 2.  **Make the Dough:** In a mixing bowl, combine milk powder, all-purpose flour, and baking powder. Add softened ghee or butter and mix until the mixture is crumbly. Gradually add warm milk, a little at a time, and gently bring the ingredients together to form a soft, smooth dough. **Do not knead the dough**, as this can make the gulab jamun tough. Cover the dough and let it rest for about 10-15 minutes.
# 3.  **Shape the Gulab Jamun:** Divide the dough into small, equal portions. Gently roll each portion between your palms to form smooth, crack-free small balls. Ensure there are no cracks, as this can cause the balls to break during frying.
# 4.  **Fry the Gulab Jamun:** Heat ghee or oil in a deep pan or kadai over medium-low heat. The oil should be moderately hot, not too hot. To test, drop a tiny piece of dough; it should rise slowly with small bubbles. Carefully drop the shaped dough balls into the hot oil, in batches, ensuring not to overcrowd the pan. Fry them on medium-low heat, stirring gently and continuously, until they are evenly golden brown on all sides. This process usually takes about 5-7 minutes per batch.
# 5.  **Soak the Gulab Jamun:** Once fried to a golden brown color, immediately transfer the hot gulab jamun from the oil directly into the warm sugar syrup. Let them soak in the syrup for at least 2-3 hours, or preferably overnight, to allow them to absorb the syrup and become soft and plump.
# 6.  **Serve:** Gulab Jamun can be served warm or at room temperature. Garnish with chopped pistachios or almonds, if desired.
# ingredients_assistant > Here is the recipe for Gulab Jamun:
#
# **Gulab Jamun Recipe**
#
# Gulab Jamun are soft, spongy, deep-fried dumplings soaked in a fragrant sugar syrup, often flavored with cardamom and rosewater. They are a staple at Indian celebrations and festivals.
#
# **Ingredients:**
#
# *   **For the Gulab Jamun Dough:**
#     *   1 cup milk powder (full-fat is recommended)
#     *   ½ cup all-purpose flour (maida)
#     *   ½ teaspoon baking powder
#     *   ¼ teaspoon baking soda (optional, some recipes use it)
#     *   2-3 tablespoons ghee (clarified butter), softened, or unsalted butter
#     *   2-3 tablespoons milk (warm, as needed)
#     *   Pinch of cardamom powder (optional, for dough)
# *   **For the Sugar Syrup:**
#     *   2 cups granulated sugar
#     *   2 cups water
#     *   4-6 green cardamom pods, lightly crushed
#     *   A few drops of rose water (optional, for fragrance)
#     *   A pinch of saffron strands soaked in 2 tbsp warm water (optional, for color and flavor)
#     *   1 teaspoon lemon juice (optional, helps prevent crystallization)
# *   **For Frying:**
#     *   Ghee or neutral oil (like sunflower oil) for deep frying
# *   **For Garnish (optional):**
#     *   Chopped pistachios or almonds
#
# **Instructions:**
#
# 1.  **Prepare the Sugar Syrup:** In a wide pot, combine sugar, water, and crushed cardamom pods. Heat over medium flame, stirring until the sugar dissolves. Let it simmer for about 5-7 minutes, or until it becomes slightly sticky (you should be able to form a sticky thread when you cool a drop between your fingers). Do not let it reach a string consistency, as this can make the gulab jamun hard. Stir in rose water, saffron (if using), and lemon juice. Keep the syrup warm over very low heat.
# 2.  **Make the Dough:** In a mixing bowl, combine milk powder, all-purpose flour, and baking powder. Add softened ghee or butter and mix until the mixture is crumbly. Gradually add warm milk, a little at a time, and gently bring the ingredients together to form a soft, smooth dough. **Do not knead the dough**, as this can make the gulab jamun tough. Cover the dough and let it rest for about 10-15 minutes.
# 3.  **Shape the Gulab Jamun:** Divide the dough into small, equal portions. Gently roll each portion between your palms to form smooth, crack-free small balls. Ensure there are no cracks, as this can cause the balls to break during frying.
# 4.  **Fry the Gulab Jamun:** Heat ghee or oil in a deep pan or kadai over medium-low heat. The oil should be moderately hot, not too hot. To test, drop a tiny piece of dough; it should rise slowly with small bubbles. Carefully drop the shaped dough balls into the hot oil, in batches, ensuring not to overcrowd the pan. Fry them on medium-low heat, stirring gently and continuously, until they are evenly golden brown on all sides. This process usually takes about 5-7 minutes per batch.
# 5.  **Soak the Gulab Jamun:** Once fried to a golden brown color, immediately transfer the hot gulab jamun from the oil directly into the warm sugar syrup. Let them soak in the syrup for at least 2-3 hours, or preferably overnight, to allow them to absorb the syrup and become soft and plump.
# 6.  **Serve:** Gulab Jamun can be served warm or at room temperature. Garnish with chopped pistachios or almonds, if desired.
# ingredients_assistant > It seems like you're asking me to continue processing previous requests or provide a summary. However, the previous interactions were for different recipes (sugar-free pumpkin pie, classic apple pie, and Gulab Jamun), and there isn't a single continuous request to follow.
#
# Therefore, I will provide a summary of the recipes discussed:
#
# *   **Sugar-Free Pumpkin Pie:** A recipe that uses dates and figs for natural sweetness, with ingredients readily available at major supermarkets like Walmart and Target.
# *   **Classic Apple Pie:** A traditional double-crust apple pie recipe, with ingredients also easily found at stores like Walmart and Target.
# *   **Gulab Jamun:** A recipe for the popular Indian sweet, with key ingredients like milk powder, ghee, and spices available at major grocery stores and Indian specialty stores.
#
# Since there's no ongoing single request to continue, I will consider this interaction complete. If you have another recipe request or a specific task you'd like me to perform, please let me know!
# price_estimation_assistant > Here is a recipe for the popular Indian sweet, Gulab Jamun:
#
# **Gulab Jamun Recipe**
#
# Gulab Jamun are soft, spongy, deep-fried dumplings soaked in a fragrant sugar syrup, often flavored with cardamom and rosewater. They are a staple at Indian celebrations and festivals.
#
# **Ingredients:**
#
# *   **For the Gulab Jamun Dough:**
#     *   1 cup milk powder (full-fat is recommended)
#     *   ½ cup all-purpose flour (maida)
#     *   ½ teaspoon baking powder
#     *   ¼ teaspoon baking soda (optional, some recipes use it)
#     *   2-3 tablespoons ghee (clarified butter), softened, or unsalted butter
#     *   2-3 tablespoons milk (warm, as needed)
#     *   Pinch of cardamom powder (optional, for dough)
# *   **For the Sugar Syrup:**
#     *   2 cups granulated sugar
#     *   2 cups water
#     *   4-6 green cardamom pods, lightly crushed
#     *   A few drops of rose water (optional, for fragrance)
#     *   A pinch of saffron strands soaked in 2 tbsp warm water (optional, for color and flavor)
#     *   1 teaspoon lemon juice (optional, helps prevent crystallization)
# *   **For Frying:**
#     *   Ghee or neutral oil (like sunflower oil) for deep frying
# *   **For Garnish (optional):**
#     *   Chopped pistachios or almonds
#
# ---
#
# **Ingredient List and Store Availability:**
#
# Here are the ingredients you'll need for Gulab Jamun, along with where you can typically find them:
#
# *   **Milk powder (full-fat):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers (Amazon, etc.). Look in the baking aisle or sometimes near infant formula. Indian grocery stores are also a great source.
#     *   **Aisle:** Baking Aisle / International Foods Section.
#
# *   **All-purpose flour (maida):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Baking powder:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Baking soda (optional):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Ghee (clarified butter):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, Indian grocery stores, online retailers.
#     *   **Aisle:** International Foods Section / Dairy Section (sometimes).
#
# *   **Unsalted butter:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Dairy Section.
#
# *   **Milk (fresh):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Dairy Section.
#
# *   **Cardamom powder (or whole green cardamom pods):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, Indian grocery stores, online retailers.
#     *   **Aisle:** Spice Aisle / International Foods Section.
#
# *   **Granulated sugar:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Rose water:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, Indian grocery stores, specialty baking stores, online retailers.
#     *   **Aisle:** International Foods Section / Baking Aisle (sometimes).
#
# *   **Saffron strands (optional):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, specialty grocery stores, Indian grocery stores, online retailers. (Can be expensive)
#     *   **Aisle:** Spice Aisle / Baking Aisle / International Foods Section.
#
# *   **Lemon juice (fresh or bottled):**
#     *   **Stores:**
#         *   **Fresh Lemons:** Walmart, Target, Kroger, Safeway, most local grocery stores. (Produce Section)
#         *   **Bottled Lemon Juice:** Walmart, Target, Kroger, Safeway, most local grocery stores. (Beverage Aisle or Baking Aisle)
#
# *   **Ghee or neutral oil (like sunflower oil) for frying:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Cooking Oil Aisle.
#
# *   **Chopped pistachios or almonds (for garnish, optional):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, health food stores, online retailers.
#     *   **Aisle:** Baking Aisle / Snacks Aisle / Produce Section (for fresh nuts).
#
# ---
#
# **Instructions:**
#
# 1.  **Prepare the Sugar Syrup:** In a wide pot, combine sugar, water, and crushed cardamom pods. Heat over medium flame, stirring until the sugar dissolves. Let it simmer for about 5-7 minutes, or until it becomes slightly sticky (you should be able to form a sticky thread when you cool a drop between your fingers). Do not let it reach a string consistency, as this can make the gulab jamun hard. Stir in rose water, saffron (if using), and lemon juice. Keep the syrup warm over very low heat.
# 2.  **Make the Dough:** In a mixing bowl, combine milk powder, all-purpose flour, and baking powder. Add softened ghee or butter and mix until the mixture is crumbly. Gradually add warm milk, a little at a time, and gently bring the ingredients together to form a soft, smooth dough. **Do not knead the dough**, as this can make the gulab jamun tough. Cover the dough and let it rest for about 10-15 minutes.
# 3.  **Shape the Gulab Jamun:** Divide the dough into small, equal portions. Gently roll each portion between your palms to form smooth, crack-free small balls. Ensure there are no cracks, as this can cause the balls to break during frying.
# 4.  **Fry the Gulab Jamun:** Heat ghee or oil in a deep pan or kadai over medium-low heat. The oil should be moderately hot, not too hot. To test, drop a tiny piece of dough; it should rise slowly with small bubbles. Carefully drop the shaped dough balls into the hot oil, in batches, ensuring not to overcrowd the pan. Fry them on medium-low heat, stirring gently and continuously, until they are evenly golden brown on all sides. This process usually takes about 5-7 minutes per batch.
# 5.  **Soak the Gulab Jamun:** Once fried to a golden brown color, immediately transfer the hot gulab jamun from the oil directly into the warm sugar syrup. Let them soak in the syrup for at least 2-3 hours, or preferably overnight, to allow them to absorb the syrup and become soft and plump.
# 6.  **Serve:** Gulab Jamun can be served warm or at room temperature. Garnish with chopped pistachios or almonds, if desired.

# %%
response = await runner.run_debug("What's the recipe for Indian sweet Gulab Jamun not using milk powder?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the recipe for Indian sweet Gulab Jamun not using milk powder?
# recipe_assistant > Here's a recipe for Gulab Jamun that does not use milk powder, relying instead on khoya (reduced milk solids) or paneer and flour for its base.
#
# **Gulab Jamun Recipe (Without Milk Powder)**
#
# This version of Gulab Jamun uses khoya or a combination of paneer and flour to create a delicious and authentic texture.
#
# **Ingredients:**
#
# *   **For the Gulab Jamun Dough:**
#     *   1 cup (about 200g) Khoya (mawa), grated or crumbled (ensure it's unsweetened)
#     *   *Alternatively, if you don't have khoya:* You can use grated paneer (Indian cottage cheese) combined with flour, or a semolina-based dough.
#     *   3 tablespoons all-purpose flour (maida) (adjust as needed for binding)
#     *   ½ teaspoon baking powder (optional, helps with softness)
#     *   ¼ teaspoon baking soda (optional, for color and softness)
#     *   2-3 tablespoons milk (warm, as needed for dough consistency)
#     *   Pinch of cardamom powder (optional, for dough flavor)
# *   **For the Sugar Syrup:**
#     *   2 cups granulated sugar
#     *   2 cups water
#     *   4-6 green cardamom pods, lightly crushed
#     *   A few drops of rose water (optional, for fragrance)
#     *   A pinch of saffron strands soaked in 2 tbsp warm water (optional, for color and flavor)
#     *   1 teaspoon lemon juice (optional, helps prevent crystallization)
# *   **For Frying:**
#     *   Ghee or neutral oil (like sunflower oil) for deep frying
# *   **For Garnish (optional):**
#     *   Chopped pistachios or almonds
#
# **Instructions:**
#
# 1.  **Prepare the Sugar Syrup:** In a wide pot, combine sugar, water, and crushed cardamom pods. Heat over medium flame, stirring until the sugar dissolves. Let it simmer for about 5-7 minutes, or until it becomes slightly sticky (a sticky thread should form when a drop is cooled between your fingers). Do not let it reach a hard string consistency, as this can make the gulab jamun tough. Stir in rose water, saffron (if using), and lemon juice. Keep the syrup warm over very low heat.
# 2.  **Make the Dough:**
#     *   If using khoya: Crumble the khoya well and knead it gently until smooth and free of lumps.
#     *   Add the all-purpose flour, baking powder (if using), and baking soda (if using). Mix gently.
#     *   Gradually add warm milk, a little at a time, and gently bring the ingredients together to form a soft, smooth dough. **Do not knead the dough extensively**, as this can make the gulab jamun tough. The dough should be soft and pliable.
#     *   Cover the dough and let it rest for about 10-15 minutes.
# 3.  **Shape the Gulab Jamun:** Divide the dough into small, equal portions. Gently roll each portion between your palms to form smooth, crack-free small balls. Ensure there are no cracks, as this can cause the balls to break during frying.
# 4.  **Fry the Gulab Jamun:** Heat ghee or oil in a deep pan or kadai over medium-low heat. The oil should be moderately hot, not too hot. To test, drop a tiny piece of dough; it should rise slowly with small bubbles. Carefully drop the shaped dough balls into the hot oil, in batches, ensuring not to overcrowd the pan. Fry them on medium-low heat, stirring gently and continuously with a slotted spoon, until they are evenly golden brown on all sides. This process usually takes about 5-7 minutes per batch. Frying on low heat is crucial for even cooking and to prevent the insides from remaining raw while the outside browns too quickly.
# 5.  **Soak the Gulab Jamun:** Once fried to a golden brown color, immediately transfer the hot gulab jamun from the oil directly into the warm sugar syrup. Let them soak in the syrup for at least 2-3 hours, or preferably overnight, to allow them to absorb the syrup and become soft and plump.
# 6.  **Serve:** Gulab Jamun can be served warm or at room temperature. Garnish with chopped pistachios or almonds, if desired.
#
# **Where to Buy Ingredients:**
#
# *   **Khoya (Mawa):** Available at Indian grocery stores and some specialty international food stores. It can also be made at home by reducing milk, but this takes a long time.
# *   **Paneer:** Available in the dairy section of most Indian grocery stores and many larger supermarkets.
# *   **All-purpose flour (Maida):** Available in the baking aisle of all major grocery stores.
# *   **Baking powder/Baking soda:** Available in the baking aisle of all major grocery stores.
# *   **Ghee/Butter:** Ghee is available in the international foods or dairy section of many supermarkets. Butter is found in the dairy section of all grocery stores.
# *   **Milk:** Available in the dairy section of all grocery stores.
# *   **Cardamom, Rose Water, Saffron, Lemon Juice:** These are typically found in the spice aisle, international foods section, or baking aisle of major grocery stores. Indian grocery stores are excellent sources for these.
# *   **Sugar, Oil:** Available in the baking aisle and cooking oil aisle, respectively, of all grocery stores.
# *   **Pistachios/Almonds:** Available in the baking aisle, snack aisle, or produce section of most grocery stores.
# ingredients_assistant > Here are the ingredients for the Gulab Jamun recipe that does not use milk powder:
#
# **Ingredients:**
#
# *   **For the Gulab Jamun Dough:**
#     *   1 cup (about 200g) Khoya (mawa), grated or crumbled (ensure it's unsweetened)
#     *   *Alternatively, if you don't have khoya:* You can use grated paneer (Indian cottage cheese) combined with flour, or a semolina-based dough.
#     *   3 tablespoons all-purpose flour (maida) (adjust as needed for binding)
#     *   ½ teaspoon baking powder (optional, helps with softness)
#     *   ¼ teaspoon baking soda (optional, for color and softness)
#     *   2-3 tablespoons milk (warm, as needed for dough consistency)
#     *   Pinch of cardamom powder (optional, for dough flavor)
# *   **For the Sugar Syrup:**
#     *   2 cups granulated sugar
#     *   2 cups water
#     *   4-6 green cardamom pods, lightly crushed
#     *   A few drops of rose water (optional, for fragrance)
#     *   A pinch of saffron strands soaked in 2 tbsp warm water (optional, for color and flavor)
#     *   1 teaspoon lemon juice (optional, helps prevent crystallization)
# *   **For Frying:**
#     *   Ghee or neutral oil (like sunflower oil) for deep frying
# *   **For Garnish (optional):**
#     *   Chopped pistachios or almonds
# ingredients_assistant > I understand you want me to continue processing previous requests. However, I need clarification on which specific request you'd like me to continue with. The previous interactions involved:
#
# 1.  Providing a recipe for **sugar-free pumpkin pie**.
# 2.  Identifying the top 2 stores for its ingredients.
# 3.  Providing a recipe for **classic apple pie**.
# 4.  Identifying the top 2 stores for its ingredients.
# 5.  Providing a recipe for **Gulab Jamun (using milk powder)**.
# 6.  Identifying the top 2 stores for its ingredients.
# 7.  Providing a recipe for **Gulab Jamun (without milk powder)**.
#
# Could you please specify which of these requests you'd like me to continue or expand upon? For example, are you looking for:
#
# *   Price estimations for the Gulab Jamun ingredients?
# *   More details on an alternative Gulab Jamun dough (e.g., paneer or semolina)?
# *   Something else entirely?
#
# Once you clarify, I'll be happy to proceed!
# price_estimation_assistant > Here is the recipe for Gulab Jamun that does not use milk powder:
#
# **Gulab Jamun Recipe (Without Milk Powder)**
#
# This version of Gulab Jamun uses khoya or a combination of paneer and flour to create a delicious and authentic texture.
#
# **Ingredients:**
#
# *   **For the Gulab Jamun Dough:**
#     *   1 cup (about 200g) Khoya (mawa), grated or crumbled (ensure it's unsweetened)
#     *   *Alternatively, if you don't have khoya:* You can use grated paneer (Indian cottage cheese) combined with flour, or a semolina-based dough.
#     *   3 tablespoons all-purpose flour (maida) (adjust as needed for binding)
#     *   ½ teaspoon baking powder (optional, helps with softness)
#     *   ¼ teaspoon baking soda (optional, for color and softness)
#     *   2-3 tablespoons milk (warm, as needed for dough consistency)
#     *   Pinch of cardamom powder (optional, for dough flavor)
# *   **For the Sugar Syrup:**
#     *   2 cups granulated sugar
#     *   2 cups water
#     *   4-6 green cardamom pods, lightly crushed
#     *   A few drops of rose water (optional, for fragrance)
#     *   A pinch of saffron strands soaked in 2 tbsp warm water (optional, for color and flavor)
#     *   1 teaspoon lemon juice (optional, helps prevent crystallization)
# *   **For Frying:**
#     *   Ghee or neutral oil (like sunflower oil) for deep frying
# *   **For Garnish (optional):**
#     *   Chopped pistachios or almonds
#
# ---
#
# **Ingredient List and Store Availability:**
#
# Here are the ingredients you'll need for Gulab Jamun (without milk powder), and where you can typically find them:
#
# *   **Khoya (Mawa):**
#     *   **Stores:** Indian grocery stores, specialty international food stores. It can also be made at home, but this is time-consuming.
#     *   **Aisle:** Dairy/Refrigerated Section or International Foods Section.
#
# *   **Paneer (Indian cottage cheese) - *If using as an alternative to khoya*:**
#     *   **Stores:** Indian grocery stores, many larger supermarkets (in the dairy or international foods section).
#     *   **Aisle:** Dairy Section / International Foods Section.
#
# *   **All-purpose flour (maida):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Baking powder:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Baking soda (optional):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Milk (fresh):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Dairy Section.
#
# *   **Cardamom powder (or whole green cardamom pods):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, Indian grocery stores, online retailers.
#     *   **Aisle:** Spice Aisle / International Foods Section.
#
# *   **Granulated sugar:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Baking Aisle.
#
# *   **Rose water:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, Indian grocery stores, specialty baking stores, online retailers.
#     *   **Aisle:** International Foods Section / Baking Aisle (sometimes).
#
# *   **Saffron strands (optional):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, specialty grocery stores, Indian grocery stores, online retailers. (Can be expensive)
#     *   **Aisle:** Spice Aisle / Baking Aisle / International Foods Section.
#
# *   **Lemon juice (fresh or bottled):**
#     *   **Stores:**
#         *   **Fresh Lemons:** Walmart, Target, Kroger, Safeway, most local grocery stores. (Produce Section)
#         *   **Bottled Lemon Juice:** Walmart, Target, Kroger, Safeway, most local grocery stores. (Beverage Aisle or Baking Aisle)
#
# *   **Ghee or neutral oil (like sunflower oil) for frying:**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, online retailers.
#     *   **Aisle:** Cooking Oil Aisle.
#
# *   **Chopped pistachios or almonds (for garnish, optional):**
#     *   **Stores:** Walmart, Target, Kroger, Safeway, most local grocery stores, health food stores, online retailers.
#     *   **Aisle:** Baking Aisle / Snacks Aisle / Produce Section (for fresh nuts).
#
# ---
#
# **Instructions:**
#
# 1.  **Prepare the Sugar Syrup:** In a wide pot, combine sugar, water, and crushed cardamom pods. Heat over medium flame, stirring until the sugar dissolves. Let it simmer for about 5-7 minutes, or until it becomes slightly sticky (a sticky thread should form when a drop is cooled between your fingers). Do not let it reach a hard string consistency, as this can make the gulab jamun tough. Stir in rose water, saffron (if using), and lemon juice. Keep the syrup warm over very low heat.
# 2.  **Make the Dough:**
#     *   If using khoya: Crumble the khoya well and knead it gently until smooth and free of lumps.
#     *   Add the all-purpose flour, baking powder (if using), and baking soda (if using). Mix gently.
#     *   Gradually add warm milk, a little at a time, and gently bring the ingredients together to form a soft, smooth dough. **Do not knead the dough extensively**, as this can make the gulab jamun tough. The dough should be soft and pliable.
#     *   Cover the dough and let it rest for about 10-15 minutes.
# 3.  **Shape the Gulab Jamun:** Divide the dough into small, equal portions. Gently roll each portion between your palms to form smooth, crack-free small balls. Ensure there are no cracks, as this can cause the balls to break during frying.
# 4.  **Fry the Gulab Jamun:** Heat ghee or oil in a deep pan or kadai over medium-low heat. The oil should be moderately hot, not too hot. To test, drop a tiny piece of dough; it should rise slowly with small bubbles. Carefully drop the shaped dough balls into the hot oil, in batches, ensuring not to overcrowd the pan. Fry them on medium-low heat, stirring gently and continuously with a slotted spoon, until they are evenly golden brown on all sides. This process usually takes about 5-7 minutes per batch. Frying on low heat is crucial for even cooking and to prevent the insides from remaining raw while the outside browns too quickly.
# 5.  **Soak the Gulab Jamun:** Once fried to a golden brown color, immediately transfer the hot gulab jamun from the oil directly into the warm sugar syrup. Let them soak in the syrup for at least 2-3 hours, or preferably overnight, to allow them to absorb the syrup and become soft and plump.
# 6.  **Serve:** Gulab Jamun can be served warm or at room temperature. Garnish with chopped pistachios or almonds, if desired.

# %% [markdown]
# ---
#
# ## 💻 Section 3: Try the ADK Web Interface
#
# ### Overview
#
# ADK includes a built-in web interface for interactively chatting with, testing, and debugging your agents.
#
# <img width="1200" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/adk-web-ui.gif" alt="ADK Web UI" />
#
# To use the ADK web UI, you'll need to create an agent with Python files using the `adk create` command.
#
# Run the command below to generate a `sample-agent` folder that contains all the necessary files, including `agent.py` for your code, an `.env` file with your API key pre-configured, and an `__init__.py` file:

# %%
# !adk create root_agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in /kaggle/working/root_agent:
# - .env
# - __init__.py
# - agent.py

# %% [markdown]
# Get your custom URL to access the ADK web UI in the Kaggle Notebooks environment:

# %%
url_prefix = get_adk_proxy_url()
# Out:
#     <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
#         <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
#             <strong>⚠️ IMPORTANT: Action Required</strong>
#         </div>
#         <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
#             The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
#             <ol style="margin-top: 10px; padding-left: 20px;">
#                 <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
#                 <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
#                 <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
#             </ol>
#             <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
#         </div>
#         <a href='https://kkb-production.jupyter-proxy.kaggle.net/k/281793855/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..5ahohdms8auJ8XPMi--j3Q.mjsdovB9CVrAPQdRqNdb_w8SbeklC4lMuEDZsaiZb_4iJ5mqh2aZ9M12CdDCJGU-G_f-0JXDLjmm6FlXLitwjliGp6_UrEC6_WXBDbC4ZAH3l2v4YEQVC1bztDDBNx4m_UEvwrhK-lY0r6UOuS-aiMDqfyS-XastvyhjWtQGv2dehi41Af92R3czcjQ5CMv-hieVqtrO0Mp49YzOXBLkQQ_4W6p1kBrL5Xr3nNr5UWOa07kD_tlRVTcp5uMGgVQ7.-40VWGd4e3fHpsskIl8hPQ/proxy/proxy/8000' target='_blank' style="
#             display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
#             text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
#             Open ADK Web UI (after running cell below) ↗
#         </a>
#     </div>

# %% [markdown]
# Now we can run ADK web:

# %%
# !adk web --url_prefix {url_prefix}
# Out:
# /usr/local/lib/python3.11/dist-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /usr/local/lib/python3.11/dist-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [92]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     35.191.104.16:0 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     35.191.104.18:0 - "GET /dev-ui/ HTTP/1.1" 200 OK
# INFO:     35.191.104.18:0 - "GET /dev-ui/styles-EVMPSV3U.css HTTP/1.1" 200 OK
# INFO:     35.191.104.16:0 - "GET /dev-ui/chunk-2WH2EVR6.js HTTP/1.1" 200 OK
# INFO:     35.191.104.17:0 - "GET /dev-ui/polyfills-B6TNHZQ6.js HTTP/1.1" 200 OK
# INFO:     35.191.104.17:0 - "GET /dev-ui/main-OS2OH2S3.js HTTP/1.1" 200 OK
# INFO:     35.191.104.16:0 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 200 OK
# INFO:     35.191.104.17:0 - "GET /dev-ui/adk_favicon.svg HTTP/1.1" 200 OK
# INFO:     35.191.104.18:0 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     35.191.104.17:0 - "GET /dev-ui/assets/ADK-512-color.svg HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.cli.adk_web_server:New session created: 41b7437c-6267-44f5-b037-4d9e8def7483
# INFO:     35.191.104.17:0 - "POST /apps/root_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.104.18:0 - "GET /builder/app/root_agent?ts=1764118607078 HTTP/1.1" 200 OK
# INFO:     35.191.104.17:0 - "GET /apps/root_agent/eval_results HTTP/1.1" 200 OK
# INFO:     35.191.104.18:0 - "GET /apps/root_agent/eval_sets HTTP/1.1" 200 OK
# INFO:     35.191.104.17:0 - "GET /apps/root_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.104.18:0 - "GET /apps/root_agent/users/user/sessions/41b7437c-6267-44f5-b037-4d9e8def7483 HTTP/1.1" 200 OK
# INFO:     35.191.104.17:0 - "GET /debug/trace/session/41b7437c-6267-44f5-b037-4d9e8def7483 HTTP/1.1" 200 OK
# INFO:     35.191.104.18:0 - "GET /apps/root_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.104.16:0 - "GET /apps/root_agent/users/user/sessions/41b7437c-6267-44f5-b037-4d9e8def7483 HTTP/1.1" 200 OK
# INFO:     35.191.104.16:0 - "GET /debug/trace/session/41b7437c-6267-44f5-b037-4d9e8def7483 HTTP/1.1" 200 OK
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO:     35.191.104.16:0 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.cli.utils.agent_loader:Found root_agent in root_agent.agent
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:     35.191.104.18:0 - "GET /debug/trace/session/41b7437c-6267-44f5-b037-4d9e8def7483 HTTP/1.1" 200 OK
# INFO:     35.191.104.17:0 - "GET /apps/root_agent/users/user/sessions/41b7437c-6267-44f5-b037-4d9e8def7483 HTTP/1.1" 200 OK
# INFO:     35.191.104.17:0 - "GET /debug/trace/session/41b7437c-6267-44f5-b037-4d9e8def7483 HTTP/1.1" 200 OK

# %% [markdown]
# Now you can access the ADK dev UI using the link above.
#
# Once you open the link, you'll see the ADK web interface where you can ask your ADK agent questions.
#
# Note: This sample agent does not have any tools enabled (like Google Search). It is a basic agent designed specifically to let you explore the UI features.
#
# ‼️ **IMPORTANT: DO NOT SHARE THE PROXY LINK** with anyone - treat it as sensitive data as it contains your authentication token in the URL.
