# %% [markdown]
# # Agents Intensive - Capstone Project - Monisha Shah
#
# **Kaggle 5-day Agents course!**
#
# Creating agents to get the recipes for sugar free deserts along with Ingredients.
#
# Using a Sequential Agents to retrieve the recipe for the desert and where to buy the ingredients from.

# %% [markdown]
# ### Install dependencies google agent development kit library
#
# The Kaggle Notebooks environment includes a pre-installed version of the [google-adk](https://google.github.io/adk-docs/) library for Python and its required dependencies, so you don't need to install additional packages in this notebook.
#
# To install and use ADK in your own Python development environment outside of this course, you can do so by running:
#
# ```
# pip install google-adk
# ```

# %% [markdown]
# ### Configure your Gemini API Key
#
# This notebook uses the [Gemini API](https://ai.google.dev/gemini-api/docs), which requires authentication.
#
# **1. Get your API key**
#
# If you don't have one already, create an [API key in Google AI Studio](https://aistudio.google.com/app/api-keys).
#
# **2. Add the key to Kaggle Secrets**
#
# Next, you will need to add your API key to your Kaggle Notebook as a Kaggle User Secret.
#
# 1. In the top menu bar of the notebook editor, select `Add-ons` then `Secrets`.
# 2. Create a new secret with the label `GOOGLE_API_KEY`.
# 3. Paste your API key into the "Value" field and click "Save".
# 4. Ensure that the checkbox next to `GOOGLE_API_KEY` is selected so that the secret is attached to the notebook.
#
# **3. Authenticate in the notebook**
#
# Run the cell below to complete authentication.

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ### Import ADK components
#
# Now, import the specific components you'll need from the Agent Development Kit and the Generative AI library. This keeps your code organized and ensures we have access to the necessary building blocks.

# %%
from google.adk.agents import Agent, LlmAgent, SequentialAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import Runner, InMemoryRunner
from google.adk.sessions import InMemorySessionService
from google.adk.memory import InMemoryMemoryService
from google.adk.tools import google_search
from google.genai import types

from google.adk.tools import load_memory, preload_memory



from google.adk.tools.mcp_tool.mcp_toolset import McpToolset
from google.adk.tools.tool_context import ToolContext
from google.adk.tools.mcp_tool.mcp_session_manager import StdioConnectionParams
from mcp import StdioServerParameters

from google.adk.apps.app import App, ResumabilityConfig
from google.adk.tools.function_tool import FunctionTool
from google.adk.sessions import InMemorySessionService

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ### Helper functions
#
# We'll define some helper functions. If you are running this outside the Kaggle environment, you don't need to do this.

# %%
# Define helper functions that will be reused throughout the notebook

from IPython.core.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# ### Configure Retry Options
#
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# ---
#
# ## AI Agent with ADK
#
# ### What is an AI Agent?
#
# You've probably used an LLM like Gemini before, where you give it a prompt and it gives you a text response.
#
# `Prompt -> LLM -> Text`
#
# An AI Agent takes this one step further. An agent can think, take actions, and observe the results of those actions to give you a better answer.
#
# `Prompt -> Agent -> Thought -> Action -> Observation -> Final Answer`
#
# In this notebook, we'll build an agent that can take the action of searching Google. Let's see the difference!

# %% [markdown]
# ### Define your agent
#
# Now, let's build our agent. We'll configure an `Agent` by setting its key properties, which tell it what to do and how to operate.
#
# To learn more, check out the documentation related to [agents in ADK](https://google.github.io/adk-docs/agents/).
#
# These are the main properties we'll set:
#
# - **name** and **description**: A simple name and description to identify our agent.
# - **model**: The specific LLM that will power the agent's reasoning. We'll use "gemini-2.5-flash-lite".
# - **instruction**: The agent's guiding prompt. This tells the agent what its goal is and how to behave.
# - **tools**: A list of [tools](https://google.github.io/adk-docs/tools/) that the agent can use. To start, we'll give it the `google_search` tool, which lets it find up-to-date information online.

# %% [markdown]
# **Agent that helps retrieve the sugar free recipes**

# %%
# Define recipe agent an LlmAgent

recipe_agent = LlmAgent(
    name="recipe_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the recipes of all sugarfree deserts using dried dates, figs and raisins.",
    instruction="You are a helpful assistant. Use Google Search to get the recipe for the sugarfree dessert.",
    tools=[google_search],
    output_key="recipe_generated",  # The result will be stored with this key.
)

print("✅ Recipe Agent defined.")
# Out:
# ✅ Recipe Agent defined.

# %% [markdown]
# **Ingredients Agent created to get all the ingredients only for the summary?**

# %%
ingredients_agent = LlmAgent(
    name="ingredients_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the recipes of all sugarfree deserts using dried dates, figs and raisins.",
    instruction="Please only give me the ingredients for the recipe for the sugarfree dessert. {recipe_generated}",
    output_key="ingredients_generated",  # The result will be stored with this key.
)

print("✅ Ingredients Agent defined.")
# Out:
# ✅ Ingredients Agent defined.

# %% [markdown]
# **Agent to retrieve the couple stores the ingredients are available at?******

# %%
store_suggestion_agent = LlmAgent(
    name="ingredients_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that get you the stores to buy the ingredients from?",
    instruction="Please give me the top 2 stores where the ingredients can be bought?. {ingredients_generated}",
    output_key="stores_suggestion_generated",  # The result will be stored with this key.
)

print("✅ Stores Suggestion Agent defined.")
# Out:
# ✅ Stores Suggestion Agent defined.

# %% [markdown]
# **Agent to get the cumulative pricing for the ingredients**

# %%
price_estimation_agent = Agent(
    name="price_estimation_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that gets you the prices of theingredients",
    instruction="Please give me the prices of all the ingredients can be bought from one store?. {ingredients_generated}",
    output_key="prices_suggestion_generated",  # The result will be stored with this key.
)

print("✅ Prices Suggestion Agent defined.")
# Out:
# ✅ Prices Suggestion Agent defined.

# %% [markdown]
# **Sequential Agent created to get the recipe, the ingredients and stores suggestion agents in a sequential manner.
#
# System with three specialized agents:
#
# recipe_agent - gets the recipe
# ingredients_agent - gets the ingredients
# stores suggestion agent - gets the stores the ingredients are available at

# %%
root_agent = SequentialAgent(
    name="RecipeWithImagePipeline",
    sub_agents=[recipe_agent, ingredients_agent, store_suggestion_agent, price_estimation_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %% [markdown]
# ### Run your agent
#
# Now it's time to bring your agent to life and send it a query. To do this, you need a [`Runner`](https://google.github.io/adk-docs/runtime/), which is the central component within ADK that acts as the orchestrator. It manages the conversation, sends our messages to the agent, and handles its responses.
#
# **a. Create an `InMemoryRunner` and tell it to use our `root_agent`:**
# **Using run_debug to send out prompt and get the answer**

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Get me a sugar free recipe for pumpkin pie with ingredients and stores where the ingredients are available"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Get me a sugar free recipe for pumpkin pie with ingredients and stores where the ingredients are available
# recipe_assistant > Here's a sugar-free pumpkin pie recipe that uses natural sweeteners like dates and figs, along with a no-bake crust option. You can find these ingredients at most major grocery stores like Walmart, Kroger, and Target, as well as health food stores like Whole Foods.
#
# **Sugar-Free Pumpkin Pie with Date-Fig Crust**
#
# This recipe offers a naturally sweetened filling and a no-bake crust.
#
# **Yields:** 8-10 servings
# **Prep time:** 30 minutes
# **Cook time:** 50-60 minutes (for filling)
#
# **Ingredients:**
#
# *   **For the No-Bake Crust:**
#     *   1 cup pitted dates (about 10-12 Medjool dates)
#     *   1/2 cup dried figs
#     *   1/4 cup almond flour or shredded unsweetened coconut
#     *   Pinch of salt
#
# *   **For the Sugar-Free Pumpkin Filling:**
#     *   1 (15-ounce) can pumpkin puree (not pumpkin pie filling)
#     *   3 large eggs
#     *   1 cup unsweetened almond milk or coconut milk
#     *   1/2 cup erythritol or monk fruit sweetener (or to taste)
#     *   2 teaspoons vanilla extract
#     *   1 teaspoon pumpkin pie spice
#     *   1 teaspoon ground cinnamon
#     *   1/2 teaspoon salt
#
# **Instructions:**
#
# 1.  **Prepare the Crust:** In a food processor, combine the pitted dates, dried figs, almond flour (or coconut), and salt. Pulse until the mixture is well combined and has a sticky, dough-like consistency. Press this mixture evenly into the bottom and up the sides of a 9-inch pie plate. You can also refrigerate the crust for about 30 minutes to firm it up before adding the filling.
# 2.  **Preheat Oven:** Preheat your oven to 350°F (175°C).
# 3.  **Make the Filling:** In a large bowl, whisk together the pumpkin puree, eggs, almond milk (or coconut milk), erythritol or monk fruit sweetener, vanilla extract, pumpkin pie spice, cinnamon, and salt until smooth and well combined.
# 4.  **Assemble the Pie:** Pour the pumpkin filling into the prepared crust.
# 5.  **Bake:** Place the pie on a baking sheet (to catch any potential drips) and bake for 50-60 minutes, or until the center is set but still slightly jiggly. A knife inserted near the center should come out clean.
# 6.  **Cool:** Let the pie cool completely on a wire rack before slicing and serving. For best results, chilling it in the refrigerator for at least a few hours or overnight will help it set fully.
#
# **Alternative Sweeteners:**
#
# *   If you prefer not to use dates and figs, you can use sugar substitutes like stevia, erythritol, or monk fruit sweetener for the crust as well, adjusting the amount to your desired sweetness.
#
# **Where to Buy Ingredients:**
#
# *   **Dates and Figs:** Found in the dried fruit section of most major supermarkets (Walmart, Kroger, Target) and health food stores (Whole Foods, Trader Joe's).
# *   **Almond Flour/Shredded Coconut:** Available in the baking aisle of supermarkets and health food stores.
# *   **Pumpkin Puree:** Canned pumpkin puree is in the baking or canned goods aisle of most grocery stores.
# *   **Eggs, Milk, Vanilla Extract, Spices, Salt:** Standard pantry staples found in any grocery store.
# *   **Erythritol/Monk Fruit Sweetener:** Look for these in the baking or health food sections of supermarkets, or in dedicated health food stores. Some online retailers also offer these sweeteners.
#
# Enjoy your delicious and naturally sweetened sugar-free pumpkin pie!
# ingredients_assistant > Here are the ingredients for the sugar-free pumpkin pie with date-fig crust:
#
# *   1 cup pitted dates (about 10-12 Medjool dates)
# *   1/2 cup dried figs
# *   1/4 cup almond flour or shredded unsweetened coconut
# *   Pinch of salt
# *   1 (15-ounce) can pumpkin puree (not pumpkin pie filling)
# *   3 large eggs
# *   1 cup unsweetened almond milk or coconut milk
# *   1/2 cup erythritol or monk fruit sweetener (or to taste)
# *   2 teaspoons vanilla extract
# *   1 teaspoon pumpkin pie spice
# *   1 teaspoon ground cinnamon
# *   1/2 teaspoon salt
#
# These ingredients can be found at most major grocery stores like Walmart, Kroger, and Target, as well as health food stores like Whole Foods and Trader Joe's.
# ingredients_assistant > The top 2 stores where the ingredients can be bought are:
#
# 1.  **Walmart**
# 2.  **Whole Foods Market**
# price_estimation_assistant > Here are the estimated prices for the ingredients of the sugar-free pumpkin pie with date-fig crust, based on typical prices at Walmart and Whole Foods Market. Please note that prices can vary by location and specific brand.
#
# **Estimated Prices at Walmart:**
#
# *   **Pitted Dates (e.g., Medjool):** $5.00 - $8.00 per 1-lb package
# *   **Dried Figs:** $4.00 - $6.00 per 8-12 oz package
# *   **Almond Flour:** $7.00 - $10.00 per 1-lb bag
#     *   *Alternatively, Shredded Unsweetened Coconut:* $2.00 - $4.00 per 14 oz bag
# *   **Salt:** $1.00 - $3.00 per container (standard table salt)
# *   **Pumpkin Puree (15 oz can):** $1.00 - $2.00
# *   **Large Eggs (dozen):** $3.00 - $5.00
# *   **Unsweetened Almond Milk (32 oz carton):** $3.00 - $4.00
#     *   *Alternatively, Unsweetened Coconut Milk (32 oz carton):* $3.00 - $4.00
# *   **Erythritol (e.g., Swerve, 12 oz bag):** $8.00 - $12.00
#     *   *Alternatively, Monk Fruit Sweetener (e.g., Lakanto, 8-16 oz bag):* $10.00 - $20.00
# *   **Vanilla Extract:** $4.00 - $8.00 per 2 oz bottle
# *   **Pumpkin Pie Spice:** $3.00 - $5.00 per spice jar
# *   **Ground Cinnamon:** $2.00 - $4.00 per spice jar
#
# **Estimated Prices at Whole Foods Market:**
#
# *   **Pitted Dates (e.g., Medjool, organic):** $7.00 - $10.00 per 1-lb package
# *   **Dried Figs:** $5.00 - $8.00 per 8-12 oz package
# *   **Almond Flour (e.g., Whole Foods 365, organic):** $8.00 - $12.00 per 1-lb bag
#     *   *Alternatively, Shredded Unsweetened Coconut (e.g., Whole Foods 365, organic):* $3.00 - $5.00 per 12 oz bag
# *   **Salt (e.g., Sea Salt):** $2.00 - $4.00 per container
# *   **Pumpkin Puree (15 oz can, organic):** $2.00 - $3.00
# *   **Large Eggs (dozen, organic/cage-free):** $5.00 - $8.00
# *   **Unsweetened Almond Milk (32 oz carton, organic):** $4.00 - $6.00
#     *   *Alternatively, Unsweetened Coconut Milk (32 oz carton, organic):* $4.00 - $6.00
# *   **Erythritol (e.g., NOW Foods, Lakanto, organic):** $10.00 - $18.00 per 12-16 oz bag
#     *   *Alternatively, Monk Fruit Sweetener (e.g., Lakanto, organic):* $12.00 - $22.00 per 8-16 oz bag
# *   **Vanilla Extract (e.g., Madagascar, organic):** $6.00 - $10.00 per 2 oz bottle
# *   **Pumpkin Pie Spice:** $4.00 - $6.00 per spice jar
# *   **Ground Cinnamon (e.g., organic):** $3.00 - $5.00 per spice jar
#
# **Total Estimated Cost:**
#
# *   **At Walmart:** Approximately $40 - $70
# *   **At Whole Foods Market:** Approximately $50 - $90
#
# These are rough estimates, and you might find better deals with specific store brands or sales.

# %% [markdown]
# 👉 Note that we are using the Python Runner directly in this notebook. You can also run agents using ADK command-line tools such as `adk run`, `adk web`, or `adk api_server`. To learn more, check out the documentation related to [runtime in ADK](https://google.github.io/adk-docs/runtime/).

# %% [markdown]
# **b. Now you can call the `.run_debug()` method to send our prompt and get an answer.**
#
# 👉 This method abstracts the process of session creation and maintenance and is used in prototyping. We'll explore "what sessions are and how to create them" on Day 3.

# %%
response = await runner.run_debug(
    "Give me a recipe for Apple Pie?  List the ingredients out separately and stores showing availability?"
)
# Out:
#  ### Continue session: debug_session_id
#
# User > Give me a recipe for Apple Pie?  List the ingredients out separately and stores showing availability?
# recipe_assistant > Here is a recipe for a sugar-free apple pie, utilizing dates for natural sweetness. This recipe uses dried apples and other dried fruits for a rich, flavorful filling.
#
# **Sugar-Free Apple Pie with Dried Fruit**
#
# This recipe gets its sweetness from dried fruits and can be made with a homemade or store-bought pie crust.
#
# **Yields:** 8-10 servings
# **Prep time:** 15 minutes + 1 hour standing time for apples
# **Cook time:** 80 minutes
#
# **Ingredients:**
#
# *   **For the Filling:**
#     *   3 cups dried apple slices
#     *   2 ½ cups apple juice or apple cider
#     *   10 ounces dried fruits (a combination of dried cherries, chopped dried figs, dried cranberries, currants, raisins)
#     *   1 tablespoon lemon zest (from 1 whole lemon)
#     *   ½ ounce cornstarch
#     *   1 teaspoon cinnamon
#     *   1 pinch grated nutmeg
#     *   *Optional:* 1/2 cup pitted dates, chopped, for extra sweetness
#     *   *Optional:* 1/3 cup raisins
#     *   *Optional:* Juice of ½ lemon
#
# *   **For the Crust:**
#     *   Your favorite recipe for a double-crust 9-inch pie
#     *   *Alternatively, for a no-sugar-added crust:* Use a recipe that incorporates ingredients like oats, whole wheat flour, walnuts, and dates.
#
# *   **For Assembly:**
#     *   1 large whole egg, lightly beaten (for egg wash)
#     *   Sanding sugar for topping (optional)
#
# **Instructions:**
#
# 1.  **Prepare the Dried Apples:** In a medium saucepan, combine the dried apple slices with apple juice or cider. Bring to a boil, then cover and let stand for 1 hour.
# 2.  **Cook the Apples:** After the standing time, cook the apples in the juice for 10 to 15 minutes, or until tender. Drain any excess liquid if necessary.
# 3.  **Prepare the Dried Fruit Mixture:** In a separate bowl, combine the other dried fruits, lemon zest, cornstarch, cinnamon, and nutmeg. If using, add the chopped dates, raisins, and lemon juice.
# 4.  **Combine Filling:** Add the cooked apple mixture to the dried fruit mixture and stir well to combine.
# 5.  **Assemble the Pie:**
#     *   Prepare your pie crust according to your recipe. Line a 9-inch pie pan with the bottom crust.
#     *   Pour the apple and dried fruit filling into the crust.
#     *   Cover with the top crust. You can create a lattice top or a full crust. Crimp the edges to seal.
#     *   Brush the top crust with the beaten egg wash and sprinkle with sanding sugar, if using.
#     *   Cut a few slits in the top crust to allow steam to escape.
# 6.  **Bake:** Preheat your oven to 400°F (200°C). Bake the pie for 50 minutes, or until the crust is golden brown and the filling is bubbling. If the crust begins to brown too quickly, you can loosely tent it with foil.
# 7.  **Cool:** Let the pie cool completely on a wire rack before slicing and serving, at least 2 hours.
#
# **Where to Find Ingredients:**
#
# *   **Dried Fruits (apples, figs, cherries, cranberries, raisins, dates):** These can be found in the dried fruit section of most major grocery stores like Walmart and Kroger, as well as health food stores such as Whole Foods Market and Trader Joe's. Bulk bins at health food stores are often a good source for dried fruits.
# *   **Apple Juice/Cider:** Available in the juice aisle of most supermarkets.
# *   **Spices (cinnamon, nutmeg):** Found in the spice aisle of any grocery store.
# *   **Lemon:** Available in the produce section of grocery stores.
# *   **Cornstarch:** Typically located in the baking aisle of supermarkets.
# *   **Pie Crust Ingredients (flour, butter, etc.):** Standard baking ingredients found in the baking aisle of grocery stores. You can also purchase pre-made pie crusts.
#
# **Sugar-Free Sweetener Alternatives:**
#
# *   If you prefer not to rely solely on dried fruits, you can explore sugar substitutes like erythritol or monk fruit sweetener for the filling, adjusting to your taste. You can also find specialized sugar-free baking ingredients at stores like Target and online retailers that offer keto and sugar-free baking supplies.
# ingredients_assistant > Here are the ingredients for the sugar-free apple pie with dried fruit:
#
# **For the Filling:**
# *   3 cups dried apple slices
# *   2 ½ cups apple juice or apple cider
# *   10 ounces dried fruits (a combination of dried cherries, chopped dried figs, dried cranberries, currants, raisins)
# *   1 tablespoon lemon zest (from 1 whole lemon)
# *   ½ ounce cornstarch
# *   1 teaspoon cinnamon
# *   1 pinch grated nutmeg
# *   *Optional:* 1/2 cup pitted dates, chopped, for extra sweetness
# *   *Optional:* 1/3 cup raisins
# *   *Optional:* Juice of ½ lemon
#
# **For the Crust:**
# *   Your favorite recipe for a double-crust 9-inch pie
# *   *Alternatively, for a no-sugar-added crust:* Use a recipe that incorporates ingredients like oats, whole wheat flour, walnuts, and dates.
#
# **For Assembly:**
# *   1 large whole egg, lightly beaten (for egg wash)
# *   Sanding sugar for topping (optional)
#
# **Stores Showing Availability:**
#
# *   **Dried Fruits (apples, figs, cherries, cranberries, raisins, dates):**
#     *   Walmart
#     *   Kroger
#     *   Whole Foods Market
#     *   Trader Joe's
# *   **Apple Juice/Cider:**
#     *   Walmart
#     *   Kroger
#     *   Whole Foods Market
#     *   Any major supermarket
# *   **Spices (cinnamon, nutmeg):**
#     *   Walmart
#     *   Kroger
#     *   Whole Foods Market
#     *   Any major supermarket
# *   **Lemon:**
#     *   Walmart
#     *   Kroger
#     *   Whole Foods Market
#     *   Any major supermarket
# *   **Cornstarch:**
#     *   Walmart
#     *   Kroger
#     *   Whole Foods Market
#     *   Any major supermarket
# *   **Pie Crust Ingredients (flour, butter, etc.) or Pre-made Pie Crusts:**
#     *   Walmart
#     *   Kroger
#     *   Whole Foods Market
#     *   Any major supermarket
# ingredients_assistant > The top 2 stores where the ingredients for the sugar-free apple pie with dried fruit can be bought are:
#
# 1.  **Walmart**
# 2.  **Kroger**
# price_estimation_assistant > Here is a recipe for a classic apple pie, along with a list of ingredients and the stores where you can find them.
#
# **Classic Apple Pie**
#
# This recipe focuses on a traditional apple pie with a flaky crust and a sweet, spiced apple filling.
#
# **Yields:** 8-10 servings
# **Prep time:** 30 minutes
# **Cook time:** 50-60 minutes
#
# **Ingredients:**
#
# *   **For the Crust:**
#     *   2 ½ cups all-purpose flour
#     *   1 teaspoon salt
#     *   1 cup (2 sticks) cold unsalted butter, cut into cubes
#     *   ½ cup ice water (or as needed)
#     *   *Alternatively:* 1 package (2 crusts) refrigerated pie crusts
#
# *   **For the Filling:**
#     *   6-8 medium apples (about 3 lbs), such as Granny Smith, Honeycrisp, or a mix, peeled, cored, and sliced ¼-inch thick
#     *   ¾ cup granulated sugar (adjust to taste and apple sweetness)
#     *   2 tablespoons all-purpose flour (or cornstarch)
#     *   1 teaspoon ground cinnamon
#     *   ¼ teaspoon ground nutmeg
#     *   1 tablespoon lemon juice
#     *   2 tablespoons unsalted butter, cut into small pieces
#
# *   **For Assembly:**
#     *   1 large egg, lightly beaten (for egg wash)
#     *   1 tablespoon granulated sugar (for topping, optional)
#
# **Instructions:**
#
# 1.  **Make the Crust:**
#     *   In a large bowl, whisk together flour and salt.
#     *   Cut in the cold butter using a pastry blender or your fingertips until the mixture resembles coarse crumbs with some pea-sized pieces of butter.
#     *   Gradually add ice water, 1 tablespoon at a time, mixing until the dough just comes together. Do not overmix.
#     *   Divide the dough in half, flatten each half into a disc, wrap in plastic wrap, and refrigerate for at least 30 minutes.
#     *   *Alternatively:* Use pre-made refrigerated pie crusts according to package directions.
#
# 2.  **Prepare the Filling:**
#     *   In a large bowl, combine the sliced apples, granulated sugar, flour (or cornstarch), cinnamon, nutmeg, and lemon juice. Toss gently to coat the apples evenly.
#
# 3.  **Assemble the Pie:**
#     *   Preheat your oven to 400°F (200°C).
#     *   On a lightly floured surface, roll out one disc of dough into a 12-inch circle. Carefully transfer it to a 9-inch pie plate. Trim any excess dough, leaving about a 1-inch overhang.
#     *   Pour the apple filling into the crust. Dot the top of the filling with the small pieces of butter.
#     *   Roll out the second disc of dough. Place it over the filling. Trim the excess dough, leaving a 1-inch overhang. Crimp the edges of the top and bottom crusts together to seal. Cut several slits in the top crust to allow steam to escape.
#     *   Brush the top crust with the beaten egg wash and sprinkle with sugar, if desired.
#
# 4.  **Bake:**
#     *   Place the pie on a baking sheet (to catch any drips).
#     *   Bake for 20 minutes at 400°F (200°C).
#     *   Reduce the oven temperature to 375°F (190°C) and continue baking for another 30-40 minutes, or until the crust is golden brown and the filling is bubbling. If the crust starts to brown too quickly, loosely tent it with foil.
#
# 5.  **Cool:**
#     *   Let the pie cool completely on a wire rack for at least 2-3 hours before slicing and serving. This allows the filling to set properly.
#
# ---
#
# **Ingredients and Stores Showing Availability:**
#
# Here are the ingredients for the Classic Apple Pie, with stores where you can find them:
#
# *   **All-Purpose Flour:**
#     *   **Walmart:** Baking aisle
#     *   **Kroger:** Baking aisle
#     *   **Whole Foods Market:** Baking aisle
#     *   **Trader Joe's:** Baking aisle
#
# *   **Salt:**
#     *   **Walmart:** Baking aisle
#     *   **Kroger:** Baking aisle
#     *   **Whole Foods Market:** Baking aisle
#     *   **Trader Joe's:** Baking aisle
#
# *   **Unsalted Butter:**
#     *   **Walmart:** Dairy aisle
#     *   **Kroger:** Dairy aisle
#     *   **Whole Foods Market:** Dairy aisle
#     *   **Trader Joe's:** Dairy aisle
#
# *   **Apples (e.g., Granny Smith, Honeycrisp):**
#     *   **Walmart:** Produce section
#     *   **Kroger:** Produce section
#     *   **Whole Foods Market:** Produce section
#     *   **Trader Joe's:** Produce section
#
# *   **Granulated Sugar:**
#     *   **Walmart:** Baking aisle
#     *   **Kroger:** Baking aisle
#     *   **Whole Foods Market:** Baking aisle
#     *   **Trader Joe's:** Baking aisle
#
# *   **Cornstarch (if using as an alternative to flour):**
#     *   **Walmart:** Baking aisle
#     *   **Kroger:** Baking aisle
#     *   **Whole Foods Market:** Baking aisle
#     *   **Trader Joe's:** Baking aisle
#
# *   **Ground Cinnamon:**
#     *   **Walmart:** Spice aisle
#     *   **Kroger:** Spice aisle
#     *   **Whole Foods Market:** Spice aisle
#     *   **Trader Joe's:** Spice aisle
#
# *   **Ground Nutmeg:**
#     *   **Walmart:** Spice aisle
#     *   **Kroger:** Spice aisle
#     *   **Whole Foods Market:** Spice aisle
#     *   **Trader Joe's:** Spice aisle
#
# *   **Lemon:**
#     *   **Walmart:** Produce section
#     *   **Kroger:** Produce section
#     *   **Whole Foods Market:** Produce section
#     *   **Trader Joe's:** Produce section
#
# *   **Large Egg:**
#     *   **Walmart:** Dairy/Refrigerated aisle
#     *   **Kroger:** Dairy/Refrigerated aisle
#     *   **Whole Foods Market:** Dairy/Refrigerated aisle
#     *   **Trader Joe's:** Dairy/Refrigerated aisle
#
# *   **Refrigerated Pie Crusts (if using pre-made):**
#     *   **Walmart:** Refrigerated section near doughs and biscuits
#     *   **Kroger:** Refrigerated section near doughs and biscuits
#     *   **Whole Foods Market:** Refrigerated section near doughs and biscuits
#     *   **Trader Joe's:** Refrigerated section near doughs and biscuits

# %% [markdown]
# You can see a summary of ADK and its available languages in the response.
#
# ### How does it work?
#
# The agent performed a Google Search to get the latest information about ADK, and it knew to use this tool because:
#
# 1. The agent inspects and is aware of which tools it has available to use.
# 2. The agent's instructions specify the use of the search tool to get current information or if it is unsure of an answer.
#
# The best way to see the full, detailed trace of the agent's thoughts and actions is in the **ADK web UI**, which we'll set up later in this notebook.
#
# And we'll cover more detailed workflows for logging and observability later in the course.

# %% [markdown]
# ### 🚀 Checking out other sugar free recipes

# %%
response = await runner.run_debug("What's the recipe for Indian sweet Gulab Jamun?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the recipe for Indian sweet Gulab Jamun?
# recipe_assistant > Here is a popular recipe for Gulab Jamun, a classic Indian sweet:
#
# **Gulab Jamun Recipe**
#
# Gulab Jamun are soft, melt-in-your-mouth, deep-fried dough balls soaked in a fragrant sugar syrup. They are a quintessential Indian dessert, perfect for celebrations and festivals.
#
# **Yields:** Approximately 26-30 Gulab Jamuns
# **Prep time:** 30 minutes (plus 30 minutes resting time for dough)
# **Cook time:** 20-30 minutes for frying + 3 hours for soaking
#
# **Ingredients:**
#
# *   **For the Dough:**
#     *   100g milk powder (full-cream recommended for richness)
#     *   60g all-purpose flour (maida)
#     *   20g semolina (rava)
#     *   ¼ teaspoon baking powder
#     *   20g unsalted butter, melted
#     *   80ml whole milk (adjust as needed for dough consistency)
#     *   *Optional:* 200g khoya (milk solids) or paneer, grated, if making traditionally
#
# *   **For the Sugar Syrup:**
#     *   500g granulated sugar
#     *   500ml water
#     *   6 green cardamom pods, lightly crushed
#     *   A few strands of saffron
#     *   1 tablespoon rose water
#     *   *Optional:* 1 ice cube or juice of ½ lemon to prevent crystallization.
#
# *   **For Frying:**
#     *   Vegetable oil or ghee (clarified butter)
#
# *   **For Garnish (Optional):**
#     *   Chopped pistachios or almonds
#
# **Instructions:**
#
# 1.  **Prepare the Sugar Syrup:** In a saucepan, combine sugar, water, crushed cardamom pods, and saffron. Bring to a boil over medium-high heat, stirring until the sugar dissolves. Reduce heat to a simmer and cook until the syrup is sticky and forms a thin thread when a drop is pulled between your fingers (about 5 minutes). Do not overcook, or it will become hard. Remove from heat, stir in rose water and lemon juice (if using). Cover and set aside to keep warm.
#
# 2.  **Make the Dough:** In a bowl, whisk together milk powder, all-purpose flour, semolina, and baking powder. If using khoya or paneer, add it now and mix well. Add the melted butter and gradually add milk, mixing gently until a soft, pliable dough forms. Do not knead vigorously; just bring the ingredients together. The dough should be smooth and crack-free. Cover the dough and let it rest for about 20-30 minutes.
#
# 3.  **Shape the Gulab Jamuns:** Divide the dough into small, equal portions. Gently roll each portion between your palms to form smooth, crack-free balls. Ensure there are no cracks, as this can cause them to break during frying.
#
# 4.  **Fry the Gulab Jamuns:** Heat oil or ghee in a deep pan over medium-low heat. The oil should be medium hot, not smoking hot. To test, drop a tiny piece of dough; it should rise slowly with bubbles. Gently drop the dough balls into the hot oil in batches, being careful not to overcrowd the pan. Fry them on medium-low heat, stirring gently and continuously to ensure even browning. Fry until they are golden brown and slightly firm.
#
# 5.  **Soak in Syrup:** Once fried, immediately transfer the hot gulab jamuns into the warm sugar syrup. Let them soak for at least 3 hours, or preferably longer, to allow them to absorb the syrup and become soft and juicy. For an even richer flavor and texture, you can gently heat the syrup with the jamuns in it for a minute or two on low flame after adding them.
#
# 6.  **Serve:** Garnish with chopped pistachios or almonds if desired. Gulab Jamun can be served warm or at room temperature.
#
# **Where to Buy Ingredients:**
#
# *   **Milk Powder, All-Purpose Flour, Semolina, Baking Powder, Sugar, Cardamom Pods, Saffron, Rose Water, Vegetable Oil/Ghee:** These are staple ingredients and can be found in the baking, spice, and cooking oil aisles of most major supermarkets like **Walmart**, **Kroger**, and **Target**. Indian grocery stores or specialty food stores like **Ambika Veg and Vegan Shop** are also excellent sources for authentic ingredients.
# *   **Khoya/Mawa or Paneer:** These dairy products can be found in the dairy section of Indian grocery stores. In some larger supermarkets with international food sections, you might also find them.
# *   **Pre-made Gulab Jamun Mix:** If you prefer a quicker option, pre-made mixes are widely available at Indian grocery stores, specialty food stores, and online retailers like **Walmart** (online) and **Uber Eats** (for local delivery of packaged goods).
# ingredients_assistant > Here are the ingredients for Gulab Jamun:
#
# *   100g milk powder (full-cream recommended for richness)
# *   60g all-purpose flour (maida)
# *   20g semolina (rava)
# *   ¼ teaspoon baking powder
# *   20g unsalted butter, melted
# *   80ml whole milk (adjust as needed for dough consistency)
# *   *Optional:* 200g khoya (milk solids) or paneer, grated, if making traditionally
# *   500g granulated sugar
# *   500ml water
# *   6 green cardamom pods, lightly crushed
# *   A few strands of saffron
# *   1 tablespoon rose water
# *   *Optional:* 1 ice cube or juice of ½ lemon to prevent crystallization.
# *   Vegetable oil or ghee (clarified butter)
# *   *Optional:* Chopped pistachios or almonds
# ingredients_assistant > The top 2 stores where the ingredients for Gulab Jamun can be bought are:
#
# 1.  **Walmart**
# 2.  **Ambika Veg and Vegan Shop** (or any local Indian grocery store)
# price_estimation_assistant > Here are the estimated prices for the ingredients needed to make Gulab Jamun, based on typical prices at Walmart and Ambika Veg and Vegan Shop (or a similar local Indian grocery store). Prices can vary significantly by location, brand, and specific product.
#
# **Estimated Prices at Walmart:**
#
# *   **Milk Powder (e.g., Nestle Nido, 14 oz can):** $6.00 - $10.00
# *   **All-Purpose Flour (Maida, e.g., Gold Medal, 5 lb bag):** $3.00 - $5.00 (you'll only need 60g)
# *   **Semolina (Rava, e.g., fine semolina, 1-2 lb box):** $2.00 - $4.00
# *   **Baking Powder (e.g., Arm & Hammer, 8 oz):** $1.00 - $3.00
# *   **Unsalted Butter (e.g., Land O'Lakes, 1 lb):** $4.00 - $6.00 (you'll only need 20g)
# *   **Whole Milk (e.g., gallon):** $3.00 - $5.00 (you'll only need 80ml)
# *   **Khoya/Mawa or Paneer (if available, sometimes hard to find):** Prices vary greatly, potentially $5.00 - $10.00 for a small quantity if found.
# *   **Granulated Sugar (e.g., C&H, 4 lb bag):** $3.00 - $5.00 (you'll only need 500g)
# *   **Green Cardamom Pods (e.g., small jar/pack):** $5.00 - $10.00 (can be expensive)
# *   **Saffron (e.g., small container):** $10.00 - $30.00+ (can be very expensive)
# *   **Rose Water (e.g., Alif, 5 fl oz bottle):** $3.00 - $6.00
# *   **Ice Cube / Lemon:** Minimal cost, usually found in your kitchen or $0.50 - $1.00 at the produce section.
# *   **Vegetable Oil (e.g., large jug):** $5.00 - $10.00 (you'll need a good amount for deep frying)
# *   **Ghee (Clarified Butter, e.g., 15 oz container):** $10.00 - $20.00 (more expensive than oil)
# *   **Chopped Pistachios/Almonds (for garnish, e.g., 4-8 oz bag):** $5.00 - $15.00
#
# **Estimated Prices at Ambika Veg and Vegan Shop (or similar Indian Grocery Store):**
#
# *   **Milk Powder (Full-cream, various brands like Amul, 1 lb pouch):** $4.00 - $7.00
# *   **All-Purpose Flour (Maida, Indian brands, 2 lb bag):** $2.00 - $3.00
# *   **Semolina (Rava, finer Indian varieties, 1-2 lb bag):** $2.00 - $3.00
# *   **Baking Powder:** Similar to Walmart, $1.00 - $3.00
# *   **Unsalted Butter:** Similar to Walmart, $4.00 - $6.00
# *   **Whole Milk:** Similar to Walmart, $3.00 - $5.00
# *   **Khoya/Mawa (fresh or dried, often available):** $5.00 - $10.00 for a decent quantity.
# *   **Granulated Sugar (Indian brands, 1-2 kg bag):** $3.00 - $5.00
# *   **Green Cardamom Pods (often sold in larger, more economical packs):** $7.00 - $15.00 for a good-sized pack.
# *   **Saffron (higher quality, often available):** $15.00 - $40.00+ for a good quantity.
# *   **Rose Water (Indian brands, larger bottles available):** $3.00 - $5.00
# *   **Ice Cube / Lemon:** Minimal cost.
# *   **Vegetable Oil / Ghee:** Ghee is often sold in larger, more economical sizes ($15.00 - $30.00 for 1-2 lbs). Vegetable oil is comparable to Walmart.
# *   **Chopped Pistachios/Almonds:** Often available in bulk or larger, more economical bags, $6.00 - $15.00.
#
# **Total Estimated Cost for Ingredients:**
#
# *   **Shopping primarily at Walmart:** Approximately **$40 - $90** (This can vary significantly based on whether you buy khoya, choose ghee, and the price of saffron).
# *   **Shopping primarily at Ambika Veg and Vegan Shop:** Approximately **$35 - $80** (Potentially more cost-effective for some Indian-specific ingredients like khoya, cardamom, and ghee, but saffron can still be a major cost).
#
# **Note on Specialty Items:** The cost of saffron and good quality cardamom pods can significantly impact the overall price. Khoya can also be a pricier ingredient if you can find it. Using vegetable oil for frying will be cheaper than ghee.

# %%
response = await runner.run_debug("What's the recipe for Indian sweet Gulab Jamun not using milk powder?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the recipe for Indian sweet Gulab Jamun not using milk powder?
# recipe_assistant > Here's a recipe for Gulab Jamun made without milk powder, focusing on using wheat flour and semolina for a soft texture.
#
# **Gulab Jamun Without Milk Powder (Wheat Flour & Semolina Base)**
#
# This recipe creates delicious Gulab Jamuns using common pantry staples like wheat flour and semolina. Khoya is traditionally used, but this version offers a great alternative.
#
# **Yields:** Approximately 20-25 Gulab Jamuns
# **Prep time:** 25 minutes (plus 30 minutes resting time for dough)
# **Cook time:** 20-30 minutes for frying + 3 hours for soaking
#
# **Ingredients:**
#
# *   **For the Dough:**
#     *   ½ cup all-purpose flour (maida)
#     *   ¼ cup semolina (rava)
#     *   2 tablespoons all-purpose flour (additional, if needed for dough consistency)
#     *   ¼ teaspoon baking powder
#     *   2 tablespoons butter or ghee, melted
#     *   ½ cup whole milk, lukewarm (adjust as needed for dough consistency)
#     *   *Optional:* A pinch of salt to enhance flavor.
#
# *   **For the Sugar Syrup:**
#     *   2 cups granulated sugar
#     *   2 cups water
#     *   2-3 green cardamom pods, lightly crushed
#     *   A few strands of saffron (optional, for color and aroma)
#     *   1 tablespoon rose water (optional, for fragrance)
#     *   *Optional:* Juice of ½ lemon or 1 ice cube to prevent crystallization
#
# *   **For Frying:**
#     *   Vegetable oil or ghee (clarified butter) for deep frying
#
# *   **For Garnish (Optional):**
#     *   Chopped pistachios or almonds
#
# **Instructions:**
#
# 1.  **Prepare the Sugar Syrup:** In a saucepan, combine sugar, water, crushed cardamom pods, and saffron (if using). Heat over medium-high heat, stirring until the sugar dissolves. Bring to a boil, then reduce heat to a simmer. Cook for about 5-7 minutes until the syrup reaches a slightly sticky consistency (it should form a thin thread when a drop is pulled between your fingers). Stir in rose water and lemon juice (if using). Remove from heat, cover, and keep warm.
#
# 2.  **Make the Dough:** In a mixing bowl, whisk together the all-purpose flour, semolina, and baking powder. Add the melted butter or ghee and mix well. Gradually add the lukewarm milk, a little at a time, and mix gently to form a soft, pliable dough. Do not knead vigorously, as this can make the gulab jamuns hard. The dough should be smooth and free of cracks. If the dough is too stiff, add a little more milk; if too soft, add a teaspoon or two of the additional all-purpose flour. Cover the dough and let it rest for 20-30 minutes.
#
# 3.  **Shape the Gulab Jamuns:** Divide the dough into small, equal portions. Gently roll each portion between your palms to form smooth, crack-free balls. Ensure there are no cracks, as this can cause them to break during frying. Greasing your hands lightly with oil can help in rolling smooth balls.
#
# 4.  **Fry the Gulab Jamuns:** Heat vegetable oil or ghee in a deep pan over medium-low heat. The oil should be moderately hot, not smoking. To test the temperature, drop a tiny piece of dough; it should rise slowly with gentle bubbles. Carefully add the dough balls to the hot oil in batches, ensuring not to overcrowd the pan. Fry on medium-low heat, stirring gently and continuously to ensure even browning. Fry until the gulab jamuns turn a uniform golden brown color.
#
# 5.  **Soak in Syrup:** Immediately transfer the hot, fried gulab jamuns into the warm sugar syrup. Let them soak for at least 3 hours, or preferably longer, to absorb the syrup and become soft and juicy. For an even richer texture, you can gently heat the syrup with the gulab jamuns in it for a minute or two on low heat after adding them.
#
# 6.  **Serve:** Garnish with chopped pistachios or almonds, if desired. Gulab Jamuns are best served warm or at room temperature.
#
# **Where to Buy Ingredients:**
#
# *   **All-Purpose Flour (Maida), Semolina (Rava), Granulated Sugar, Baking Powder, Vegetable Oil/Ghee, Cardamom Pods, Saffron, Rose Water, Pistachios/Almonds:** These ingredients are readily available at most major grocery stores like **Walmart**, **Kroger**, and **Target**. For a wider selection of Indian spices and specialty items like rose water, saffron, and ghee, **Ambika Veg and Vegan Shop** or other local Indian grocery stores are excellent choices.
# *   **Whole Milk, Butter:** Available in the dairy section of all major supermarkets.
# *   **Lemons:** Found in the produce section of grocery stores.
# ingredients_assistant > Here are the ingredients for Gulab Jamun made without milk powder:
#
# *   ½ cup all-purpose flour (maida)
# *   ¼ cup semolina (rava)
# *   2 tablespoons all-purpose flour (additional, if needed for dough consistency)
# *   ¼ teaspoon baking powder
# *   2 tablespoons butter or ghee, melted
# *   ½ cup whole milk, lukewarm (adjust as needed for dough consistency)
# *   *Optional:* A pinch of salt to enhance flavor.
# *   2 cups granulated sugar
# *   2 cups water
# *   2-3 green cardamom pods, lightly crushed
# *   A few strands of saffron (optional, for color and aroma)
# *   1 tablespoon rose water (optional, for fragrance)
# *   *Optional:* Juice of ½ lemon or 1 ice cube to prevent crystallization
# *   Vegetable oil or ghee (clarified butter) for deep frying
# *   *Optional:* Chopped pistachios or almondsThe top 2 stores where the ingredients for Gulab Jamun (without milk powder) can be bought are:
#
# 1.  **Walmart**
# 2.  **Kroger**
# ingredients_assistant > I have processed the previous requests as instructed. If you have any more requests, please let me know! Otherwise, I'm happy to provide a summary or exit.
# price_estimation_assistant > Here are the estimated prices for the ingredients to make Gulab Jamun without milk powder, based on typical prices at Walmart and Kroger. Please remember that prices can vary by location, brand, and specific sales.
#
# **Estimated Prices at Walmart:**
#
# *   **All-Purpose Flour (Maida, e.g., Gold Medal, 5 lb bag):** $3.00 - $5.00 (you'll only need a little over ½ cup)
# *   **Semolina (Rava, e.g., fine semolina, 1-2 lb box):** $2.00 - $4.00
# *   **Baking Powder (e.g., Arm & Hammer, 8 oz):** $1.00 - $3.00
# *   **Butter (Unsalted, e.g., Land O'Lakes, 1 lb):** $4.00 - $6.00 (you'll only need 2 tablespoons)
# *   **Ghee (Clarified Butter, e.g., 15 oz container):** $10.00 - $20.00 (if you choose ghee for melting and frying)
#     *   *Alternatively, Vegetable Oil (e.g., large jug):* $5.00 - $10.00 (for melting and frying)
# *   **Whole Milk (e.g., gallon):** $3.00 - $5.00 (you'll only need ½ cup)
# *   **Granulated Sugar (e.g., C&H, 4 lb bag):** $3.00 - $5.00 (you'll only need 2 cups)
# *   **Green Cardamom Pods (e.g., small jar/pack):** $5.00 - $10.00 (can be a bit pricey)
# *   **Saffron (e.g., small container):** $10.00 - $30.00+ (this is often the most expensive ingredient)
# *   **Rose Water (e.g., Alif, 5 fl oz bottle):** $3.00 - $6.00
# *   **Lemon:** $0.50 - $1.00 (or use one you have)
# *   **Chopped Pistachios/Almonds (for garnish, e.g., 4-8 oz bag):** $5.00 - $15.00
#
# **Estimated Prices at Kroger:**
#
# *   **All-Purpose Flour (Maida, e.g., Kroger Brand, 5 lb bag):** $2.50 - $4.00
# *   **Semolina (Rava, e.g., Kroger Brand, 1-2 lb box):** $2.00 - $3.50
# *   **Baking Powder (e.g., Kroger Brand, 8 oz):** $1.00 - $2.50
# *   **Butter (Unsalted, e.g., Kroger Brand, 1 lb):** $3.50 - $5.50
# *   **Ghee (Clarified Butter, e.g., Kroger Brand or other brands, 15 oz container):** $8.00 - $18.00
#     *   *Alternatively, Vegetable Oil (e.g., Kroger Brand, large jug):* $4.50 - $8.50
# *   **Whole Milk (e.g., Kroger Brand gallon):** $3.00 - $4.50
# *   **Granulated Sugar (e.g., Kroger Brand, 4 lb bag):** $2.50 - $4.00
# *   **Green Cardamom Pods (various brands):** $5.00 - $10.00
# *   **Saffron (small container):** $10.00 - $30.00+
# *   **Rose Water (e.g., KTC, 5 fl oz bottle):** $3.00 - $5.00
# *   **Lemon:** $0.50 - $1.00
# *   **Chopped Pistachios/Almonds (e.g., Kroger Brand or other brands, 4-8 oz bag):** $5.00 - $12.00
#
# **Total Estimated Cost for Ingredients:**
#
# *   **Shopping primarily at Walmart:** Approximately **$40 - $90**
# *   **Shopping primarily at Kroger:** Approximately **$35 - $80**
#
# **Key Considerations for Cost:**
#
# *   **Saffron:** This is the most variable and expensive ingredient. If you skip it or use a very small amount, the total cost will decrease significantly.
# *   **Ghee vs. Oil:** Using vegetable oil for frying is more economical than using ghee.
# *   **Garnish:** Pistachios and almonds add to the cost; they are optional.
# *   **Bulk Purchases:** Buying larger quantities of staples like flour, sugar, and oil can be more cost-effective in the long run, though you'll have a higher upfront cost.
# *   **Brand Choice:** Store brands (like Kroger's) are generally cheaper than national brands.

# %% [markdown]
# ---
#
# ## 💻 Section 3: Try the ADK Web Interface
#
# ### Overview
#
# ADK includes a built-in web interface for interactively chatting with, testing, and debugging your agents.
#
# <img width="1200" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/adk-web-ui.gif" alt="ADK Web UI" />
#
# To use the ADK web UI, you'll need to create an agent with Python files using the `adk create` command.
#
# Run the command below to generate a `sample-agent` folder that contains all the necessary files, including `agent.py` for your code, an `.env` file with your API key pre-configured, and an `__init__.py` file:

# %%
# !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in /kaggle/working/sample-agent:
# - .env
# - __init__.py
# - agent.py

# %% [markdown]
# Get your custom URL to access the ADK web UI in the Kaggle Notebooks environment:

# %%
url_prefix = get_adk_proxy_url()
# Out:
#     <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
#         <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
#             <strong>⚠️ IMPORTANT: Action Required</strong>
#         </div>
#         <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
#             The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
#             <ol style="margin-top: 10px; padding-left: 20px;">
#                 <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
#                 <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
#                 <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
#             </ol>
#             <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
#         </div>
#         <a href='https://kkb-production.jupyter-proxy.kaggle.net/k/281768775/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..KoxPWqNGNMuYLHSy0KW9ew.JdOsiYIVAYwOdnxJm7IAbtu2rseWp26Fu2D3DZCnniXnyKMswJqtKqobHRA_Kcujd3omADDNfNpa04bz8QcIbKTHej5AZ2AHe7QQt1RspK2xtbUPb-KEvAg7hNMK9RHJxXoeQo_vTzW6ire1uWfGnpJhx93Och0GePiOKE519t_S280wjgGSIReRG3t8oBXBlEj0GLzaWp_eCl4Cc7Z_PADasA7dNOBE7yAMQJrwKdk0YPtMeB6X0mZ7TOXLhU-X.W410quPTT0AX1aan6YEMtg/proxy/proxy/8000' target='_blank' style="
#             display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
#             text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
#             Open ADK Web UI (after running cell below) ↗
#         </a>
#     </div>

# %% [markdown]
# Now we can run ADK web:

# %%
# !adk web --url_prefix {url_prefix}
# Out:
# /usr/local/lib/python3.11/dist-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /usr/local/lib/python3.11/dist-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [95]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)

# %% [markdown]
# Now you can access the ADK dev UI using the link above.
#
# Once you open the link, you'll see the ADK web interface where you can ask your ADK agent questions.
#
# Note: This sample agent does not have any tools enabled (like Google Search). It is a basic agent designed specifically to let you explore the UI features.
#
# ‼️ **IMPORTANT: DO NOT SHARE THE PROXY LINK** with anyone - treat it as sensitive data as it contains your authentication token in the URL.
